# %% [markdown]
# # Парсинг HTML. BeautifulSoup.

# %% [markdown]
# ### Скрейпинг и парсинг данных одной страницы.

# %%
# Импорт необходимых библиотек
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Путь к странице с данным
website = "https://www.aptekaru.de/online-shop/allergie-heuschnupfen"

# %%
# GET-запрос к серверу
page = requests.get(website)

# %%
# Проверка статуса ответа сервера
page.status_code
# Out:
# 200

# %%
type(page.text)

# %%
type(page.content)

# %%
# Парсинг данных 
soup = BeautifulSoup(page.content, 'html.parser')

# %%
page.text

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <script>
#     let cookiesAccepted = document.cookie.indexOf("cookie-policy-accepted") != -1;
#     let month = new Array("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct", "Nov", "Dec");
#     let days = new Array("Sun","Mon","Tue","Wed","Thu","Fri","Sat");
#     let date = new Date();
#     let expiration = new Date(date.setDate(date.getDate() + 365));
#
#     if ( ! cookiesAccepted) {
#         document.cookie = 'cc_analytics=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#         document.cookie = 'cc_advertising=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#     }
# </script>
# <title>
#             Аллергия и аллергический ринит
#      - apteka</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="global" name="distribution">
# <meta content="" name="description"/>
# <meta content="" name="keywords"/>
# <meta content="Mauve Webshopsystem 3" name="generator"/>
# <meta content="3 Days" name="revisit-after"/>
# <meta content="9e571d2e04b1a424" name="yandex-verification">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.aptekaru.de/online-shop/allergie-heuschnupfen" rel="canonical"/>
# <link href="/online-shop/allergie-heuschnupfen?order_by=Relevance&amp;order_direction=DESC&amp;row=24" rel="next"/>
# <link href="/assets/master/tmp/main.min.34fd9a78.css" rel="stylesheet" type="text/css"/>
# <script src="/assets/master/js/src/available.js" type="text/javascript"></script>
# <script>
#     window.meshop = {"customer":{"signedIn":false},"form":{"titles":{"1":{"titleId":"1","name":"\u0413\u043e\u0441\u043f\u043e\u0434\u0438\u043d"},"2":{"titleId":"2","name":"\u0413\u043e\u0441\u043f\u043e\u0436\u0430"},"3":{"titleId":"3","name":"\u0421\u0435\u043c\u044c\u044f"},"4":{"titleId":"4","name":"\u0424\u0438\u0440\u043c\u0430"}}}};
# </script><script>
# window.dataLayer = window.dataLayer ||[];
# window.dataLayer.push({
#                     'ecommerce': {
#                                             }
# });
# </script>
# <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-K2FC265');
# </script><style type="text/css">#content {
#     max-width: 100%;
# }
#
# html[debug-cms=true] [debug="cms"] {
#     border: 2px solid #71b263 !important;
#     min-height: 20px;
# }
#
# html[debug-cms=true] [debug="cms"]::after {
#     content: "";
#     display: table;
#     clear: both;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     box-shadow: 0px 2px 20px rgba(0,0,0,.7);
#     position: relative;
#     z-index: 9998;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     border: 2px solid #54b200 !important;
# }
#
# html[debug-cms=true] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     background-color: #54b200 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
#
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     right: 0;
#     bottom: 0;
#     left:auto;
#     top:auto;
#     z-index: 9999;
#     background-color: #EC7007 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
# html[debug-cms=true] [debug="cms"] [debug="cms"],
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover{
#     border: 2px solid #EC7007 !important;
# }
#
# [debug="shoptext"] {
#     text-decoration: none !important;
#     border: 0 !important;
# }
#
# html[debug-shoptext=true] [debug="shoptext"] {
#     outline: 2px solid #ab65b2 !important;
#     position: relative;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover {
#     outline: 2px solid #833db2 !important;
#     z-index: 9999;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover::after {
#     background-color: #833db2 !important;
#     content: attr(title);
#     color: #fff !important;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     padding-left: 2px;
#     padding-right: 2px;
#     font-size: 12px;
#     line-height: 1.2;
# }
# </style></meta></meta></head>
# <body class="">
# <div id="app">
# <header>
# <div class=" promotion-banner relative bg-primary text-white text-center px-3 py-2 hide">
# <div class="inline-block lg:ml-22">
# <span class="inline-block mb-2">
# <p><b>В связи с актуальной ситуацией отправка пакетов на Украину, в Россию и в Белоруссию, а также оформление заказов из этих стран, к сожалению невозможны.</b></p>
# </span>
# <a class="button-light ml-2" href="/versandkosten">Mehr</a>
# </div>
# <a class="absolute text-white flex items-center pin-r pin-y mr-3 ml-4" href="#">
# <span class="promotion-close">x</span>
# </a>
# </div>
# <aside class="hidden md:block">
# <div class="container container--wide">
# <div class="flex pt-3 pb-2 items-center justify-between border-b border-grey">
# <div class="hidden-print">
# </div>
# <div class="text-right">
# </div>
# <div></div>
# </div>
# </div>
# </aside>
# <div class="sticky pin-t z-10 md:relative container container--wide px-0">
# <div class="md:bg-transparent mx-auto flex flex-wrap md:flex-no-wrap items-center p-3 md:py-3 lg:pr-6 w-full justify-between flex-row">
# <a class="block w-64 sm:w-auto sm:max-w-full" href="https://www.aptekaru.de/" title="Стартовая страница">
# <img alt="Logo" src="/documents/logo/Logo Apteka 282x66.png"/>
# </a>
# <div class="user-nav md:order-last flex my-3 md:my-0">
# <a @click.prevent="emitEvent('offcanvas_open_account')" class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary" href="https://www.aptekaru.de/account/login" title="Зарегистрируйтесь здесь.">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-login-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-login.svg"/>
# </div>
# <div class="hidden sm:block">Войти</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary relative" href="https://www.aptekaru.de/notepad">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-merkzettel-hover.svg?v=1"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-merkzettel.svg"/>
# </div>
# <div class="hidden sm:block">Список отложенных товаров</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:pr-0 relative" href="https://www.aptekaru.de/checkout/cart">
# <mini-cart class="text-sm"></mini-cart>
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-cart-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-cart.svg"/>
# </div>
# <div class="hidden sm:block">Корзина</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:hidden flex flex-col justify-between -mr-1 sm:-mr-0 pr-0" href="#mobileNavigation" id="mobileNavigationButton" title="Все категории">
# <i class="fa fa-bars text-5xl mt-1" id="mobileNavigationIcon"></i>
# <div class="hidden sm:block">МЕНЮ</div>
# </a>
# </div>
# <speedfinder-search :is-primary="true" :is-products-only="false" :min-search-text-length="speedfinder.minSearchTextLength" :overwrite-search-term="speedfinder.searchTerm" @speedfinder_search_term_changed="onSpeedfinderSearchTermChange" class="w-full h-16 xl:ml-16 md:h-24 md:max-w-sm lg:max-w-md xl:max-w-lg">
# <form action="https://www.aptekaru.de/suche.html" class="w-full h-16 xl:ml-16 md:h-24" method="GET">
# <div class="relative bg-white z-10 flex shadow-md h-full">
# <input autocomplete="off" class="w-full pl-3" maxlength="128" name="term" placeholder="Товар, фармацевтический номер, действующее вещество..." type="text"/>
# <button class="bg-grey-light-dark hover:bg-grey-light-darker text-white text-base md:text-4xl m-0 px-4" tabindex="-1" type="submit" value="1">
# <i class="fa fa-search"></i>
# </button>
# </div>
# </form>
# </speedfinder-search>
# </div>
# </div>
# <div class="bg-grey">
# <div class="container container--mid relative page-wrap-top hidden sm:block">
# <img class="absolute pin-r -mt-2 hidden lg:block" src="/assets/master/img/design/apotheken-a-rund.png" style="z-index: 1;"/>
# <nav class="navmenu c-navmenu py-3 hidden-xs hidden-sm hidden-print">
# <ul class="o-nav o-nav__level o-nav__level--1 o-nav--inline "><li class="o-nav__item o-nav__item--has-children"><a class=" active" href="/online-shop" title="Все категории">Все категории</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><
a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/nieren-blasentee" title="Чаи для почек и мочевого пузыря">Чаи для почек и мочевого пузыря</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/schlaf-nerventee" title="Чаи для укрепления нервной системы и хорошего сна">Чаи для укрепления нервной системы и хорошего сна</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/teezubehoer" title="Товары для приготовления чая">Товары для приготовления чая</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/zahn-mundpflege" title="Уход за ротовой полостью и зубами">Уход за ротовой полостью и зубами</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/atemfrische" title="Свежесть дыхания">Свежесть дыхания</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/mundduschen" title="Ирригаторы">Ирригаторы</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/mundtrockenheit" title="Сухость во рту">Сухость во рту</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/mundwasser-spuelungen" title="Ополаскиватели и жидкости для полоскания рта">Ополаскиватели и жидкости для полоскания рта</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnaufhellung" title="Отбеливание зубов">Отбеливание зубов</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnbuersten" title="Зубные щетки">Зубные щетки</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnersatz" title="Зубные протезы">Зубные протезы</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnfleischentzuendung" title="Гингивит">Гингивит</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnpasta-zahncreme" title="Зубная паста">Зубная паста</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer" title="Сопутсвтующие товары по уходу за полостью рта">Сопутсвтующие товары по уходу за полостью рта</a></li></ul>
# </li></ul>
# </nav>
# </div>
# </div>
# </header>
# <div>
# <div class="container my-2">
# </div>
# </div>
# <main class="section-main container page-wrap-bottom">
# <ol class="breadcrumb bg-transparent">
# <li><a class="text-grey-darker hover:text-grey-dark text-sm" href="https://www.aptekaru.de/" title="Стартовая страница">Стартовая страница</a></li>
# <li class="active text-grey-darker text-sm">Аллергия и аллергический ринит</li>
# </ol>
# <div class="row">
# <div class="col-md-3 visible-lg visible-md hidden-print">
# <h2 class="h2">категории</h2>
# <ul class="navigation-list list-reset font-sari leading-loose level-1">
# <li class="Selected">
# <a class="active" href="/online-shop/allergie-heuschnupfen" title="Аллергия и аллергический ринит">Аллергия и аллергический ринит</a>
# <ul class="list-reset pl-2 level-2">
# <li>
# <a href="/online-shop/allergie-heuschnupfen/allergie-heuschnupfen-unterstuetzend" title="Поддерживающие препараты при аллергии и аллергическом рините">Поддерживающие препараты при аллергии и аллергическом рините</a>
# </li>
# <li>
# <a href="/online-shop/allergie-heuschnupfen/soforthilfe" title="Неотложная помощь">Неотложная помощь</a>
# </li>
# <li>
# <a href="/online-shop/allergie-heuschnupfen/vorbeugend" title="Профилактика">Профилактика</a>
# </li>
# <li>
# <a href="/online-shop/allergie-heuschnupfen/zubehoer" title="Сопутствующие товары">Сопутствующие товары</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/online-shop/schmerzmittel" title="Болеутоляющие средства">Болеутоляющие средства</a>
# </li>
# <li>
# <a href="/online-shop/raucherentwoehnung" title="Борьба с курением">Борьба с курением</a>
# </li>
# <li>
# <a href="/online-shop/vitamine-mineralien-enzyme" title="Витамины, минералы и ферменты">Витамины, минералы и ферменты</a>
# </li>
# <li>
# <a href="/online-shop/alles-fuer-die-frau" title="Все для женщин">Все для женщин</a>
# </li>
# <li>
# <a href="/online-shop/augen-nase-ohren" title="Глаза, нос, уши">Глаза, нос, уши</a>
# </li>
# <li>
# <a href="/online-shop/diabetes" title="Диабет">Диабет</a>
# </li>
# <li>
# <a href="/online-shop/vegan-vegetarisch" title="Для веганов и вегетарианцев">Для веганов и вегетарианцев</a>
# </li>
# <li>
# <a href="/online-shop/haus-reiseapotheke" title="Домашняя аптечка и аптечка для путешествий">Домашняя аптечка и аптечка для путешествий</a>
# </li>
# <li>
# <a href="/online-shop/magen-darm-verdauung" title="Желудок, кишечник и пищеварение">Желудок, кишечник и пищеварение</a>
# </li>
# <li>
# <a href="/online-shop/geschenkideen" title="Идеи для подарков">Идеи для подарков</a>
# </li>
# <li>
# <a href="/online-shop/buecher-cd-dvd" title="Книги, CD и DVD">Книги, CD и DVD</a>
# </li>
# <li>
# <a href="/online-shop/haut-haare-naegel" title="Кожа, волосы, ногти">Кожа, волосы, ногти</a>
# </li>
# <li>
# <a href="/online-shop/kosmetik" title="Косметика">Косметика</a>
# </li>
# <li>
# <a href="/online-shop/marken" title="Марки">Марки</a>
# </li>
# <li>
# <a href="/online-shop/haeusliche-pflege" title="Медицинская помощь на дому">Медицинская помощь на дому</a>
# </li>
# <li>
# <a href="/online-shop/medizinische-geraete" title="Медицинские приборы">Медицинские приборы</a>
# </li>
# <li>
# <a href="/online-shop/muskeln-knochen-gelenke" title="Мышцы, кости и суставы">Мышцы, кости и суставы</a>
# </li>
# <li>
# <a href="/online-shop/natur-pflanzenheilkunde" title="Натуральные и растительные лекарственные средства">Натуральные и растительные лекарственные средства</a>
# </li>
# <li>
# <a href="/online-shop/neu-im-sortiment" title="Новое в ассортименте">Новое в ассортименте</a>
# </li>
# <li>
# <a href="/online-shop/wellness" title="Оздоровление">Оздоровление</a>
# </li>
# <li>
# <a href="/online-shop/nahrungsergaenzung" title="Пищевые добавки">Пищевые добавки</a>
# </li>
# <li>
# <a href="/online-shop/sexualitaet" title="Половая жизнь">Половая жизнь</a>
# </li>
# <li>
# <a href="/online-shop/niere-blase-prostata" title="Почки, мочевой пузырь и простата">Почки, мочевой пузырь и простата</a>
# </li>
# <li>
# <a href="/online-shop/erkaeltung-abwehr" title="Простуда и профилактика">Простуда и профилактика</a>
# </li>
# <li>
# <a href="/online-shop/themen" title="Разделы">Разделы</a>
# </li>
# <li>
# <a href="/online-shop/sale" title="Распродажа">Распродажа</a>
# </li>
# <li>
# <a href="/online-shop/familie" title="Семья">Семья</a>
# </li>
# <li>
# <a href="/online-shop/herz-kreislauf-venen" title="Сердце, система кровообращения и вены">Сердце, система кровообращения и вены</a>
# </li>
# <li>
# <a href="/online-shop/nerven-beruhigung-schlaf" title="Средства для нервной системы, успокоения и хорошего сна">Средства для нервной системы, успокоения и хорошего сна</a>
# </li>
# <li>
# <a href="/online-shop/praxisbedarf" title="Товары для клиник">Товары для клиник</a>
# </li>
# <li>
# <a href="/online-shop/staerkung-konzentration" title="Укрепление здоровья и большая концентрация">Укрепление здоровья и большая концентрация</a>
# </li>
# <li>
# <a href="/online-shop/augenpflege" title="Уход за глазами">Уход за глазами</a>
# </li>
# <li>
# <a href="/online-shop/zahn-mundpflege" title="Уход за ротовой полостью и зубами">Уход за ротовой полостью и зубами</a>
# </li>
# <li>
# <a href="/online-shop/fitness" title="Фитнес">Фитнес</a>
# </li>
# <li>
# <a href="/online-shop/tees-kraeuter" title="Чаи и травы">Чаи и травы</a>
# </li>
# </ul>
# </div>
# <div class=" col-md-9 ">
# <h1 class="h2">Обзор Аллергия и аллергический ринит</h1>
# <script type="text/javascript">
#     available.objAvailable('shop', function(o) {
#         o.description('Подробнее', 'свернуть', 100);
#     });
# </script>
# <div class="text-center">
# <style media="screen" type="text/css">
# </style>
# <div id="kairion-super"> </div>
# </div>
# <div class="hidden-md hidden-lg mb-3">
# <a class="button-primary" href="#mobileNavigation">Другие группы товаров</a>
# </div>
# <div class="row mt1 after-search">
# <form action="/online-shop/allergie-heuschnupfen" id="asnformbox" method="get" name="asnformbox">
# <input id="asntextbox" name="q" type="hidden" value="">
# <div class="col-xs-12">
# <div class="hidden-xs">
# <strong>фильтр товаров</strong>
# <p>Сузить поиск</p>
# <hr class="hr my1"/>
# </div>
# </div>
# <input id="asnfield_submit" name="searchfield_submit" type="hidden" value="1"/>
# <input name="order_by" type="hidden" value="Relevance"/>
# <input name="order_direction" type="hidden" value="DESC"/>
# <input name="range" type="hidden" value="24"/>
# <div class="clearfix"></div>
# <div class="col-xs-6 visible-xs visible-sm">
# <a class="button-primary hidden-md hidden-lg" data-toggle="collapse" href="#afterSearch">Suchfilter anzeigen</a>
# </div>
# <div class="collapse-xs collapse-sm" id="afterSearch">
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_640afc51102c9">Производитель</label>
# <div class="styled-multi-select col-12">
# <select data-label="Производитель" id="asn_filter_640afc51102c9" multiple="" name="filter[Hersteller][]">
# <option data-count="17" value="1 A Pharma GmbH">1 A Pharma GmbH</option>
# <option data-count="4" value="A. Nattermann &amp; Cie GmbH">A. Nattermann &amp; Cie GmbH</option>
# <option data-count="6" value="AbZ Pharma GmbH">AbZ Pharma GmbH</option>
# <option data-count="16" value="ALIUD Pharma GmbH">ALIUD Pharma GmbH</option>
# <option data-count="1" value="ALLERGIKA Pharma GmbH">ALLERGIKA Pharma GmbH</option>
# <option data-count="1" value="AMAZONAS Naturprodukte Handels GmbH">AMAZONAS Naturprodukte Handels GmbH</option>
# <option data-count="9" value="Aristo Pharma GmbH">Aristo Pharma GmbH</option>
# <option data-count="8" value="axicorp Pharma GmbH">axicorp Pharma GmbH</option>
# <option data-count="2" value="Bayer Vital GmbH">Bayer Vital GmbH</option>
# <option data-count="21" value="Beiersdorf AG Eucerin">Beiersdorf AG Eucerin</option>
# <option data-count="2" value="Bencard Allergie GmbH">Bencard Allergie GmbH</option>
# <option data-count="13" value="betapharm Arzneimittel GmbH">betapharm Arzneimittel GmbH</option>
# <option data-count="1" value="Biologische Heilmittel Heel GmbH">Biologische Heilmittel Heel GmbH</option>
# <option data-count="3" value="Blanco Pharma GmbH">Blanco Pharma GmbH</option>
# <option data-count="4" value="Careliv Produkte OHG">Careliv Produkte OHG</option>
# <option data-count="7" value="CEGLA Medizintechnik GmbH">CEGLA Medizintechnik GmbH</option>
# <option data-count="1" value="COMBUSTIN Pharmazeutische Präparate GmbH">COMBUSTIN Pharmazeutische Präparate GmbH</option>
# <option data-count="12" value="DERMAPHARM AG">DERMAPHARM AG</option>
# <option data-count="5" value="Dexcel Pharma GmbH">Dexcel Pharma GmbH</option>
# <option data-count="4" value="DHU-Arzneimittel GmbH &amp; Co. KG">DHU-Arzneimittel GmbH &amp; Co. KG</option>
# <option data-count="2" value="Doromed GmbH">Doromed GmbH</option>
# <option data-count="15" value="Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH">Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH</option>
# <option data-count="1" value="Dr. Loges + Co. GmbH">Dr. Loges + Co. GmbH</option>
# <option data-count="1" value="Dr. Pfleger Arzneimittel GmbH">Dr. Pfleger Arzneimittel GmbH</option>
# <option data-count="1" value="Dr. Theiss Naturwaren GmbH">Dr. Theiss Naturwaren GmbH</option>
# <option data-count="1" value="Dr. Winzer Pharma GmbH">Dr. Winzer Pharma GmbH</option>
# <option data-count="1" value="Dreluso-Pharmazeutika Dr.Elten &amp; Sohn GmbH">Dreluso-Pharmazeutika Dr.Elten &amp; Sohn GmbH</option>
# <option data-count="1" value="EB Vertriebs GmbH">EB Vertriebs GmbH</option>
# <option data-count="2" value="GALENpharma GmbH">GALENpharma GmbH</option>
# <option data-count="8" value="GlaxoSmithKline Consumer Healthcare">GlaxoSmithKline Consumer Healthcare</option>
# <option data-count="4" value="Glenmark Arzneimittel GmbH">Glenmark Arzneimittel GmbH</option>
# <option data-count="2" value="Harras Pharma Curarina Arzneimittel GmbH">Harras Pharma Curarina Arzneimittel GmbH</option>
# <option data-count="14" value="HEUMANN PHARMA GmbH &amp; Co. Generica KG">HEUMANN PHARMA GmbH &amp; Co. Generica KG</option>
# <option data-count="3" value="Hevert Arzneimittel GmbH &amp; Co. KG">Hevert Arzneimittel GmbH &amp; Co. KG</option>
# <option data-count="24" value="Hexal AG">Hexal AG</option>
# <option data-count="1" value="HLH BioPharma GmbH">HLH BioPharma GmbH</option>
# <option data-count="1" value="Homöopathisches Laboratorium Alexander Pflüger GmbH &amp; Co. KG">Homöopathisches Laboratorium Alexander Pflüger GmbH &amp; Co. KG</option>
# <option data-count="3" value="IMP GmbH International Medical Products">IMP GmbH International Medical Products</option>
# <option data-count="5" value="Johnson &amp; Johnson GmbH (OTC)">Johnson &amp; Johnson GmbH (OTC)</option>
# <option data-count="1" value="Klinge Pharma GmbH">Klinge Pharma GmbH</option>
# <option data-count="2" value="Köhler Pharma GmbH">Köhler Pharma GmbH</option>
# <option data-count="1" value="LOTA- free breath">LOTA- free breath</option>
# <option data-count="3" value="MCM KLOSTERFRAU Vertr. GmbH">MCM KLOSTERFRAU Vertr. GmbH</option>
# <option data-count="1" value="medphano Arzneimittel GmbH">medphano Arzneimittel GmbH</option>
# <option data-count="1" value="Merz Consumer Care GmbH">Merz Consumer Care GmbH</option>
# <option data-count="1" value="MIBE GmbH Arzneimittel">MIBE GmbH Arzneimittel</option>
# <option data-count="5" value="Micro Labs GmbH">Micro Labs GmbH</option>
# <option data-count="2" value="NESTMANN Pharma GmbH">NESTMANN Pharma GmbH</option>
# <option data-count="2" value="Omega Pharma Deutschland GmbH">Omega Pharma Deutschland GmbH</option>
# <option data-count="6" value="OmniVision GmbH">OmniVision GmbH</option>
# <option data-count="1" value="Param GmbH">Param GmbH</option>
# <option data-count="4" value="Pascoe pharmazeutische Präparate GmbH">Pascoe pharmazeutische Präparate GmbH</option>
# <option data-count="2" value="Penta Arzneimittel GmbH">Penta Arzneimittel GmbH</option>
# <option data-count="2" value="Pharma Liebermann GmbH">Pharma Liebermann GmbH</option>
# <option data-count="2" value="PHARMA STULLN GmbH">PHARMA STULLN GmbH</option>
# <option data-count="1" value="plantoCAPS pharm GmbH">plantoCAPS pharm GmbH</option>
# <option data-count="3" value="Pädia GmbH">Pädia GmbH</option>
# <option data-count="3" value="Queisser Pharma GmbH &amp; Co. KG">Queisser Pharma GmbH &amp; Co. KG</option>
# <option data-count="23" value="ratiopharm GmbH">ratiopharm GmbH</option>
# <option data-count="1" value="SANUM-KEHLBECK GmbH &amp; Co. KG">SANUM-KEHLBECK GmbH &amp; Co. KG</option>
# <option data-count="5" value="Sidroga Gesellschaft für Gesundheitsprodukte mbH">Sidroga Gesellschaft für Gesundheitsprodukte mbH</option>
# <option data-count="4" value="Spenglersan GmbH">Spenglersan GmbH</option>
# <option data-count="23" value="STADA Consumer Health Deutschland GmbH">STADA Consumer Health Deutschland GmbH</option>
# <option data-count="6" value="TAD Pharma GmbH">TAD Pharma GmbH</option>
# <option data-count="3" value="UCB Pharma GmbH">UCB Pharma GmbH</option>
# <option data-count="9" value="URSAPHARM Arzneimittel GmbH">URSAPHARM Arzneimittel GmbH</option>
# <option data-count="6" value="Viatris Healthcare GmbH">Viatris Healthcare GmbH</option>
# <option data-count="6" value="WALA Heilmittel GmbH">WALA Heilmittel GmbH</option>
# <option data-count="4" value="WEBER &amp; WEBER GmbH">WEBER &amp; WEBER GmbH</option>
# <option data-count="10" value="WEIDEMEYER + Co. Vertriebsges. für Medizinbedarf mbH">WEIDEMEYER + Co. Vertriebsges. für Medizinbedarf mbH</option>
# <option data-count="8" value="WELEDA AG">WELEDA AG</option>
# <option data-count="1" value="WEPA Apothekenbedarf GmbH &amp; Co KG">WEPA Apothekenbedarf GmbH &amp; Co KG</option>
# <option data-count="1" value="Zein Pharma - Germany GmbH">Zein Pharma - Germany GmbH</option>
# <option data-count="10" value="Zentiva Pharma GmbH">Zentiva Pharma GmbH</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_640afc5110324">лекарственная форма</label>
# <div class="styled-multi-select col-12">
# <select data-label="лекарственная форма" id="asn_filter_640afc5110324" multiple="" name="filter[Darreichungsform][]">
# <option data-count="6" value="Ampullen">Ampullen</option>
# <option data-count="1" value="Augen- und Nasensalbe">Augen- und Nasensalbe</option>
# <option data-count="28" value="Augentropfen">Augentropfen</option>
# <option data-count="1" value="Beutel">Beutel</option>
# <option data-count="7" value="Creme">Creme</option>
# <option data-count="2" value="Dosierspray">Dosierspray</option>
# <option data-count="8" value="Duschgel">Duschgel</option>
# <option data-count="4" value="Einzeldosispipetten">Einzeldosispipetten</option>
# <option data-count="1" value="Emulsion">Emulsion</option>
# <option data-count="121" value="Filmtabletten">Filmtabletten</option>
# <option data-count="1" value="Flaschen">Flaschen</option>
# <option data-count="1" value="Flüssigkeit">Flüssigkeit</option>
# <option data-count="1" value="Flüssigseife">Flüssigseife</option>
# <option data-count="1" value="Globuli">Globuli</option>
# <option data-count="1" value="Granulat">Granulat</option>
# <option data-count="2" value="Hartkapseln">Hartkapseln</option>
# <option data-count="7" value="Injektionslösung">Injektionslösung</option>
# <option data-count="9" value="Kapseln">Kapseln</option>
# <option data-count="7" value="Kombipackung">Kombipackung</option>
# <option data-count="1" value="Körperpflege">Körperpflege</option>
# <option data-count="5" value="Lotion">Lotion</option>
# <option data-count="4" value="Lutschtabletten">Lutschtabletten</option>
# <option data-count="4" value="Lösung">Lösung</option>
# <option data-count="2" value="Lösung für einen Vernebler">Lösung für einen Vernebler</option>
# <option data-count="12" value="Lösung zum Einnehmen">Lösung zum Einnehmen</option>
# <option data-count="5" value="Mischung">Mischung</option>
# <option data-count="4" value="Nasendosierspray">Nasendosierspray</option>
# <option data-count="40" value="Nasenspray">Nasenspray</option>
# <option data-count="1" value="Pastillen">Pastillen</option>
# <option data-count="3" value="Pflaster">Pflaster</option>
# <option data-count="4" value="Pulver">Pulver</option>
# <option data-count="2" value="Saft">Saft</option>
# <option data-count="1" value="Salbe">Salbe</option>
# <option data-count="2" value="Salz">Salz</option>
# <option data-count="1" value="Shampoo">Shampoo</option>
# <option data-count="1" value="Spray">Spray</option>
# <option data-count="1" value="Stifte">Stifte</option>
# <option data-count="49" value="Tabletten">Tabletten</option>
# <option data-count="4" value="Tabletten magensaftresistent">Tabletten magensaftresistent</option>
# <option data-count="11" value="Tropfen">Tropfen</option>
# <option data-count="1" value="Tube">Tube</option>
# <option data-count="3" value="Überzogene Tabletten">Überzogene Tabletten</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_640afc5110353">Единица измерения упаковки</label>
# <div class="styled-multi-select col-12">
# <select data-label="Единица измерения упаковки" id="asn_filter_640afc5110353" name="filter[Verpackungseinheit][]" onchange="if(this.value[0]) this.form.submit();">
# <option disabled="" selected="" value="">Единица измерения упаковки</option>
# <option data-count="27" value="g">g</option>
# <option data-count="128" value="ml">ml</option>
# <option data-count="4" value="P">P</option>
# <option data-count="231" value="St">St</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_640afc511035f">Действующее вещество</label>
# <div class="styled-multi-select col-12">
# <select data-label="Действующее вещество" id="asn_filter_640afc511035f" multiple="" name="filter[Wirkstoff][]">
# <option data-count="1" value="Acidum formicicum">Acidum formicicum</option>
# <option data-count="19" value="Azelastin hydrochlorid">Azelastin hydrochlorid</option>
# <option data-count="3" value="Bilastin">Bilastin</option>
# <option data-count="74" value="Cetirizin dihydrochlorid">Cetirizin dihydrochlorid</option>
# <option data-count="1" value="Clemastin fumarat">Clemastin fumarat</option>
# <option data-count="19" value="Cromoglicinsäure, Dinatriumsalz">Cromoglicinsäure, Dinatriumsalz</option>
# <option data-count="36" value="Desloratadin">Desloratadin</option>
# <option data-count="3" value="Dexpanthenol">Dexpanthenol</option>
# <option data-count="5" value="Dimetinden maleat">Dimetinden maleat</option>
# <option data-count="1" value="Emser Salz, natürlich">Emser Salz, natürlich</option>
# <option data-count="1" value="Euphrasia ferm 33c">Euphrasia ferm 33c</option>
# <option data-count="2" value="Fluticason 17-propionat">Fluticason 17-propionat</option>
# <option data-count="3" value="Ketotifen fumarat">Ketotifen fumarat</option>
# <option data-count="7" value="Levocabastin hydrochlorid">Levocabastin hydrochlorid</option>
# <option data-count="32" value="Levocetirizin dihydrochlorid">Levocetirizin dihydrochlorid</option>
# <option data-count="28" value="Loratadin">Loratadin</option>
# <option data-count="18" value="Mometason furoat-1-Wasser">Mometason furoat-1-Wasser</option>
# <option data-count="4" value="Orotsäure, Zinksalz-2-Wasser">Orotsäure, Zinksalz-2-Wasser</option>
# <option data-count="1" value="Tramazolin hydrochlorid-1-Wasser">Tramazolin hydrochlorid-1-Wasser</option>
# <option data-count="5" value="Xylometazolin hydrochlorid">Xylometazolin hydrochlorid</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-4 mb1">
# <label class="sr-only" for="asn_filter_640afc5110377">цена</label>
# <div class="styled-multi-select col-12">
# <select data-label="цена" id="asn_filter_640afc5110377" multiple="" name="filter[Preis][]">
# <option data-count="118" value="Preis ge 5m and Preis le 9.99m">5 € - 9,99 €</option>
# <option data-count="136" value="Preis ge 10m and Preis le 24.99m">10 € - 24,99 €</option>
# <option data-count="43" value="Preis ge 25m and Preis le 49.99m">25 € - 49,99 €</option>
# <option data-count="25" value="Preis ge 50m and Preis le 199.99m">50 € - 199,99 €</option>
# <option data-count="1" value="Preis ge 200m">&gt;= 200 €</option>
# <option data-count="67" value="Preis lt 5m">&lt; 5 €</option>
# </select>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="clearfix mb-3"></div>
# <div class="col-xs-12">
# <div class="my1">
# <a class="btn btn-reset btn-rounded btn-xs px2" href="//online-shop/allergie-heuschnupfen">Сбросить все фильтры</a>
# </div>
# </div>
# </div>
# </input></form>
# <div class="col-xs-6 visible-xs visible-sm">
# <div class="toolbar">
# <form action="/online-shop/allergie-heuschnupfen" id="toolbox" method="get" name="toolbox">
# <input id="asntextbox" name="q" type="hidden" value=""/>
# <input id="asnfield_submit" name="searchfield_submit" type="hidden" value="1"/>
# <div class="form-group row">
# <div class="col-xs-12 col-sm-8 form-inline">
# <div class="form-group hidden-xs">
# <label class="control-label" for="order_by">Сортировка:</label>
# </div>
# <div class="form-group inline-block">
# <div class="styled-multi-select styled-multi-select-minimal styled-multi-select-small multi-select-sort">
# <label class="sr-only" for="sort">Сортировка:</label>
# <select id="order_by" name="sort">
# <option selected="selected" value="Relevance-DESC">Актуальность</option>
# <option value="Name-ASC">Имя A-Z</option>
# <option value="Name-DESC">Имя Z-A</option>
# <option value="Price-ASC">Цена по возрастанию</option>
# <option value="Price-DESC">Цена по убыванию</option>
# <option value="Manufacturer-ASC">производитель A-Z</option>
# <option value="Manufacturer-DESC">производитель Z-A</option>
# </select>
# </div>
# </div>
# </div>
# <div class="col-xs-4 col-sm-4 hidden-xs">
# <div class="product-group__viewmode mb-2 text-right">
# <button @click.prevent="switchProductGroupViewMode('matrix')" class="product-group__viewmode__button product-group__viewmode__button--matrix btn btn-default active" title="Auf Matrix-Ansicht umstellen" type="button"><i class="fa fa-th"></i></button>
# <button @click.prevent="switchProductGroupViewMode('list')" class="product-group__viewmode__button product-group__viewmode__button--list btn btn-default" title="Auf Listen-Ansicht umstellen" type="button"><i class="fa fa-bars"></i></button>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <hr class="hr mb1"/>
# <div class="hidden-xs hidden-sm">
# <div class="toolbar">
# <form action="/online-shop/allergie-heuschnupfen" id="toolbox" method="get" name="toolbox">
# <input id="asntextbox" name="q" type="hidden" value=""/>
# <input id="asnfield_submit" name="searchfield_submit" type="hidden" value="1"/>
# <div class="form-group row">
# <div class="col-xs-12 col-sm-8 form-inline">
# <div class="form-group hidden-xs">
# <label class="control-label" for="order_by">Сортировка:</label>
# </div>
# <div class="form-group inline-block">
# <div class="styled-multi-select styled-multi-select-minimal styled-multi-select-small multi-select-sort">
# <label class="sr-only" for="sort">Сортировка:</label>
# <select id="order_by" name="sort">
# <option selected="selected" value="Relevance-DESC">Актуальность</option>
# <option value="Name-ASC">Имя A-Z</option>
# <option value="Name-DESC">Имя Z-A</option>
# <option value="Price-ASC">Цена по возрастанию</option>
# <option value="Price-DESC">Цена по убыванию</option>
# <option value="Manufacturer-ASC">производитель A-Z</option>
# <option value="Manufacturer-DESC">производитель Z-A</option>
# </select>
# </div>
# </div>
# </div>
# <div class="col-xs-4 col-sm-4 hidden-xs">
# <div class="product-group__viewmode mb-2 text-right">
# <button @click.prevent="switchProductGroupViewMode('matrix')" class="product-group__viewmode__button product-group__viewmode__button--matrix btn btn-default active" title="Auf Matrix-Ansicht umstellen" type="button"><i class="fa fa-th"></i></button>
# <button @click.prevent="switchProductGroupViewMode('list')" class="product-group__viewmode__button product-group__viewmode__button--list btn btn-default" title="Auf Listen-Ansicht umstellen" type="button"><i class="fa fa-bars"></i></button>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div class="products">
# <div class="row flex flex-wrap product-grid product-grid--matrix">
# <div class="product-box-container flex col-sm-6 col-md-4 col-xs-12 mb-4">
# <div class="bg-white product-box flex ">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/lorano-akut-tabletten-07222502" title="Lorano akut Tabletten">
# <img alt="Lorano akut Tabletten" src="/documents/products/Listenansicht/1009200670.jpg?ver=1677228009" style="margin: auto" title="Lorano akut Tabletten">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-48 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/lorano-akut-tabletten-07222502" title="Lorano akut Tabletten">Lorano akut Tabletten</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Tabletten</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 20 St
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 07222502
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> Hexal AG
#                                                                     </div>
# <p class="delivery-time"> <img alt="поставка невозможна" class="delivery-time-image" src="/documents/delivery_times/delivery-empty.png" title="поставка невозможна"> <small> поставка невозможна</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 20 St
#                                     <div class="pull-right">
# </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# <div class="line-through">
#                                         10,02 €
#                                     </div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-secondary ">
#
#                                         5,19 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# </div>
# <p class="small product-shipping-info">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# </div>
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://www.aptekaru.de/checkout/cart/add/product" class="text-right flex-1 justify-end product-submit-form" method="post">
# <input name="product[product_id]" type="hidden" value="42677"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# </form>
# </div>
# </div>
# </div>
# <div class="product-box-container flex col-sm-6 col-md-4 col-xs-12 mb-4">
# <div class="bg-white product-box flex ">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/desloratadin-ratiopharm-5-mg-filmtabletten-15397612" title="Desloratadin-ratiopharm 5 mg Filmtabletten">
# <img alt="Desloratadin-ratiopharm 5 mg Filmtabletten" src="/documents/products/Listenansicht/1008602857.jpg?ver=1677228009" style="margin: auto" title="Desloratadin-ratiopharm 5 mg Filmtabletten">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-51 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# ...
# </ul></li><li><a href="/online-shop/kosmetik/maennerpflege" title="Средства по уходу для мужчин">Средства по уходу для мужчин</a><ul>
# <ul class=""><li><a href="/online-shop/kosmetik/maennerpflege/anti-age" title="Антивозрастные средства">Антивозрастные средства</a></li><li><a href="/online-shop/kosmetik/maennerpflege/deo" title="Дезодоранты">Дезодоранты</a></li><li><a href="/online-shop/kosmetik/maennerpflege/falten" title="Морщины">Морщины</a></li><li><a href="/online-shop/kosmetik/maennerpflege/gesichts
</a></li><li><a href="/online-shop/zahn-mundpflege/zahnbuersten/interdentalbuersten" title="Сменные ершики для межзубных промежутков">Сменные ершики для межзубных промежутков</a></li></ul>
# </ul></li><li><a href="/online-shop/zahn-mundpflege/zahnersatz" title="Зубные протезы">Зубные протезы</a><ul>
# <ul class=""><li><a href="/online-shop/zahn-mundpflege/zahnersatz/aufbewahrung" title="Хранение">Хранение</a></li><li><a href="/online-shop/zahn-mundpflege/zahnersatz/haftmittel" title="Адгезивные средства">Адгезивные средства</a></li><li><a href="/online-shop/zahn-mundpflege/zahnersatz/reinigung" title="Очищение">Очищение</a></li></ul>
# </ul></li><li><a href="/online-shop/zahn-mundpflege/zahnfleischentzuendung" title="Гингивит">Гингивит</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpasta-zahncreme" title="Зубная паста">Зубная паста</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer" title="Сопутсвтующие товары по уходу за полостью рта">Сопутсвтующие товары по уходу за полостью рта</a><ul>
# <ul class=""><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/kaugummi" title="Жевательная резинка">Жевательная резинка</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/sonstiges" title="Прочее">Прочее</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/zahnseide-hoelzer" title="Зубная нить и зубочистки">Зубная нить и зубочистки</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/zungenreiniger" title="Скребок для языка">Скребок для языка</a></li></ul>
# </ul></li></ul>
# </ul></li></ul>
# </ul>
# </nav>
# <script type="text/javascript">
#             available.objAvailable('shop', function (o) {
#                 o.initMMenu('#mobileNavigation', true);
#             });
#         </script>
# <script type="text/javascript">window.shoptexts = {'search': {'placeholder': 'На латинице: название, PZN или дейст. вещество','noResult': 'Нет результатов','products': 'Рекомендованные товары','goToAll': 'Показать все результаты','manufacturer': 'Производитель','productGroups': 'Категории','suggestions': 'Предложения','redirects': 'Переадрессация','searching': '""Поиск результатов..."','minimumCharactersPre': 'Поиск  должен как минимум','minimumCharactersAfter': 'содержать знаков.'},'cartSummary' : {'empty' : 'Корзина пуста.','total' : 'Промежуточная сумма','priceInfo' : 'Цены Вкл. НДС" при необходимости включая стоимость доставки','addedToCart': 'добавлено в  корзину.','toCheckout': 'К оплате','shippingHeadline': 'Не хватает до бесплатной доставки','edit': 'К корзине','continueShopping': 'Продолжить покупки','crossSellingHeadline': 'Любимые продукты','crossSellingGoToProduct': 'К товару',},'offcanvas': {'continueShopping': 'Продолжить покупки'},'modal': {'close' : 'Закрыть'},'notepad': {'add_to_notepad': 'В Списке отложенных товаров','remove_from_notepad': 'Vom Merkzettel entfernen'},'revocation': {'cancel_all': 'Я хочу отказаться от всего заказа','cancel_some': 'Я хочу отказаться от следующих товаров в заказе','product_number': 'Товар №','amount': 'Количество','add_product': 'Добавить товар'}}</script>
# <script src="/assets/master/tmp/main.min.3dd417cd.js" type="text/javascript"></script>
# <script>
#         let promoBanner = document.querySelector(".promotion-banner");
#         let promoButtonClose = document.querySelector(".promotion-close");
#         if (promoBanner) {
#             let userClass = promoBanner.classList[0];
#             let cookieName = 'promoBannerClosed' + userClass;
#             let userCookie = getCookie(cookieName);
#             if(userCookie != 'closed'){
#                 promoBanner.classList.remove("hide");
#             }
#             promoButtonClose.addEventListener('click', function(e){
#                 e.preventDefault();
#                 setCookie(cookieName, 'closed', 90)
#                 promoBanner.classList.add("hide");
#             });
#         }
#
#         function getCookie(cname) {
#             var name = cname + "=";
#             var decodedCookie = decodeURIComponent(document.cookie);
#             var ca = decodedCookie.split(';');
#             for(var i = 0; i <ca.length; i++) {
#                 var c = ca[i];
#                 while (c.charAt(0) == ' ') {
#                     c = c.substring(1);
#                 }
#                 if (c.indexOf(name) == 0) {
#                     return c.substring(name.length, c.length);
#                 }
#             }
#             return "";
#         }
#
#         function setCookie(cname, cvalue, exdays) {
#             var d = new Date();
#             d.setTime(d.getTime() + (exdays*24*60*60*1000));
#             var expires = "expires="+ d.toUTCString();
#             document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/";
#         }
#     </script>
# <noscript>
# <div id="javaScriptWarning" style="width: 100%; position:fixed; bottom: 0; left:0;z-index:1000;">
# <div style="background-color: #222;opacity:0.9;color: #FFFFFF;font-size: 13px;margin: 0 auto;padding: 8px;text-align: center;line-height:18px;">
#                             Javascript не активен. <br/> Пожалуйста, активируйте Javascript в браузере, иначе будут доступны не все функции сайта.
#                         </div>
# </div>
# </noscript>
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K2FC265" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript><script>(function (init)
# {
#     var root = document.getElementsByTagName('html')[0];
#     root.setAttribute('debug-cms', true);
#     root.setAttribute('debug-shoptext', true);
#
#         })();</script></body>
# </html>

# %%
# Поиск по тегу <div>
result = soup.find_all('div', ('class','product-box-container'))

# %%
len(result)
# Out:
# 24

# %%
type(result)

# %% [markdown]
# ### Скрейпинг ссылок на каждый товар

# %%
# Первая часть ссылки
url_1 = 'https://www.aptekaru.de'

# %%
# Извлечение списка относительных ссылок на товары
url_2 = []
for i in result:
  for link in i.find_all('div', ('class','product-box__image')):
    url_2.append(link.find('a').get('href'))

# %%
len(url_2)
# Out:
# 24

# %%
url_2
# Out:
# ['/online-kaufen/lorano-akut-tabletten-07222502',
#  '/online-kaufen/desloratadin-ratiopharm-5-mg-filmtabletten-15397612',
#  '/online-kaufen/allegra-allergietabletten-20-mg-tabletten-18113578',
#  '/online-kaufen/vividrin-mometason-heuschnupfennasenspray-16581358',
#  '/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938174',
#  '/online-kaufen/allergopax-milbenspray-16807526',
#  '/online-kaufen/ipalat-hydro-med-lutschpastillen-14287703',
#  '/online-kaufen/momekort-50-g-spruehstoss-nasenspray-susp-140-fuer-erwachsene-14406639',
#  '/online-kaufen/dr-theiss-hydro-med-green-augentro-einzeldos-amp-18365038',
#  '/online-kaufen/allegra-allergietabletten-20-mg-tabletten-18181918',
#  '/online-kaufen/allegra-allergietabletten-20-mg-tabletten-18113489',
#  '/online-kaufen/mometadex-50-g-spruehstoss-nasenspray-17600980',
#  '/online-kaufen/mometadex-50-g-spruehstoss-nasenspray-17600974',
#  '/online-kaufen/tavegil-tabletten-16791883',
#  '/online-kaufen/allergodil-akut-forte-1-5-mg-ml-nasenspray-loesung-17510656',
#  '/online-kaufen/allergo-azelind-von-doppelherzpharma-17273707',
#  '/online-kaufen/allergo-momelind-von-doppelherzpharma-16665753',
#  '/online-kaufen/allergo-momelind-von-doppelherzpharma-16665747',
#  '/online-kaufen/astragalus-pro-500-50-kapseln-17885505',
#  '/online-kaufen/tetesept-meerwasser-nasenspuelsalz-17365059',
#  '/online-kaufen/levocetirizin-fairmed-5-mg-filmtabletten-16392249',
#  '/online-kaufen/levocetirizin-fairmed-5-mg-filmtabletten-16392226',
#  '/online-kaufen/levocetirizin-fairmed-5-mg-filmtabletten-16392203',
#  '/online-kaufen/daosin-tabletten-16872989']

# %%
import urllib.parse

# %%
# Объединение двух частей ссылки в абсолютный путь и создание списка со ссылками на каждый товар, расположенный на странице
url_joined = []

for link in url_2:
  url_joined.append(urllib.parse.urljoin(url_1, link))

# %%
url_joined
# Out:
# ['https://www.aptekaru.de/online-kaufen/lorano-akut-tabletten-07222502',
#  'https://www.aptekaru.de/online-kaufen/desloratadin-ratiopharm-5-mg-filmtabletten-15397612',
#  'https://www.aptekaru.de/online-kaufen/allegra-allergietabletten-20-mg-tabletten-18113578',
#  'https://www.aptekaru.de/online-kaufen/vividrin-mometason-heuschnupfennasenspray-16581358',
#  'https://www.aptekaru.de/online-kaufen/desloratadin-heumann-5-mg-filmtabletten-16938174',
#  'https://www.aptekaru.de/online-kaufen/allergopax-milbenspray-16807526',
#  'https://www.aptekaru.de/online-kaufen/ipalat-hydro-med-lutschpastillen-14287703',
#  'https://www.aptekaru.de/online-kaufen/momekort-50-g-spruehstoss-nasenspray-susp-140-fuer-erwachsene-14406639',
#  'https://www.aptekaru.de/online-kaufen/dr-theiss-hydro-med-green-augentro-einzeldos-amp-18365038',
#  'https://www.aptekaru.de/online-kaufen/allegra-allergietabletten-20-mg-tabletten-18181918',
#  'https://www.aptekaru.de/online-kaufen/allegra-allergietabletten-20-mg-tabletten-18113489',
#  'https://www.aptekaru.de/online-kaufen/mometadex-50-g-spruehstoss-nasenspray-17600980',
#  'https://www.aptekaru.de/online-kaufen/mometadex-50-g-spruehstoss-nasenspray-17600974',
#  'https://www.aptekaru.de/online-kaufen/tavegil-tabletten-16791883',
#  'https://www.aptekaru.de/online-kaufen/allergodil-akut-forte-1-5-mg-ml-nasenspray-loesung-17510656',
#  'https://www.aptekaru.de/online-kaufen/allergo-azelind-von-doppelherzpharma-17273707',
#  'https://www.aptekaru.de/online-kaufen/allergo-momelind-von-doppelherzpharma-16665753',
#  'https://www.aptekaru.de/online-kaufen/allergo-momelind-von-doppelherzpharma-16665747',
#  'https://www.aptekaru.de/online-kaufen/astragalus-pro-500-50-kapseln-17885505',
#  'https://www.aptekaru.de/online-kaufen/tetesept-meerwasser-nasenspuelsalz-17365059',
#  'https://www.aptekaru.de/online-kaufen/levocetirizin-fairmed-5-mg-filmtabletten-16392249',
#  'https://www.aptekaru.de/online-kaufen/levocetirizin-fairmed-5-mg-filmtabletten-16392226',
#  'https://www.aptekaru.de/online-kaufen/levocetirizin-fairmed-5-mg-filmtabletten-16392203',
#  'https://www.aptekaru.de/online-kaufen/daosin-tabletten-16872989']

# %% [markdown]
# ### Извлечение данных одного товара

# %%
# Ссылка на первый товар
first_link = url_joined[0]

# %%
# GET-запрос серверу
response = requests.get(first_link)

# %%
# Парсинг данных
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <script>
#     let cookiesAccepted = document.cookie.indexOf("cookie-policy-accepted") != -1;
#     let month = new Array("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct", "Nov", "Dec");
#     let days = new Array("Sun","Mon","Tue","Wed","Thu","Fri","Sat");
#     let date = new Date();
#     let expiration = new Date(date.setDate(date.getDate() + 365));
#
#     if ( ! cookiesAccepted) {
#         document.cookie = 'cc_analytics=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#         document.cookie = 'cc_advertising=false; expires='+ days[expiration.getDay()] +', '+ expiration.getDate() +' '+ month[expiration.getMonth()] +' '+ expiration.getFullYear() +' '+ expiration.getHours() +':'+ expiration.getMinutes() +':'+ expiration.getSeconds() +' UTC; path=/';
#     }
# </script>
# <title>Lorano akut Tabletten 20 St - Диабет - apteka | Лекарства из Германии в Apteka.de</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="global" name="distribution">
# <meta content="Заказать лекарства из Германии с доставкой по Москве и России. Интернет аптека Германии. Apteka.de" name="description"/>
# <meta content="аптека купить лекарства медикаменты германия заказать онлайн доставка" name="keywords"/>
# <meta content="Mauve Webshopsystem 3" name="generator"/>
# <meta content="3 Days" name="revisit-after"/>
# <meta content="9e571d2e04b1a424" name="yandex-verification">
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://www.aptekaru.de/online-kaufen/lorano-akut-tabletten-01797130" rel="canonical"/>
# <link href="/assets/master/tmp/main.min.34fd9a78.css" rel="stylesheet" type="text/css"/>
# <script src="/assets/master/js/src/available.js" type="text/javascript"></script>
# <script>
#     window.meshop = {"customer":{"signedIn":false},"form":{"titles":{"1":{"titleId":"1","name":"\u0413\u043e\u0441\u043f\u043e\u0434\u0438\u043d"},"2":{"titleId":"2","name":"\u0413\u043e\u0441\u043f\u043e\u0436\u0430"},"3":{"titleId":"3","name":"\u0421\u0435\u043c\u044c\u044f"},"4":{"titleId":"4","name":"\u0424\u0438\u0440\u043c\u0430"}}}};
# </script><script>
# window.dataLayer = window.dataLayer ||[];
# window.dataLayer.push({
#                     'ecommerce': {
#                 'detail': {
#             'actionField': {'list': ' Аллергия и аллергический ринит'},
#             'products': [
#                                 {
#                     'name': 'Lorano akut Tabletten',
#                     'id': '07222502',
#                     'price': '5.19',
#                     'brand': 'Hexal AG',
#                     'category': 'Аллергия и аллергический ринит',
#                                                                         'dimension1': 'Neukunde',
#                                                     'dimension2': 'not logged in',
#                                                     'dimension3': '',
#                                                             },
#                             ]
#         },
#                                             }
# });
# </script>
# <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-K2FC265');
# </script><style type="text/css">#content {
#     max-width: 100%;
# }
#
# html[debug-cms=true] [debug="cms"] {
#     border: 2px solid #71b263 !important;
#     min-height: 20px;
# }
#
# html[debug-cms=true] [debug="cms"]::after {
#     content: "";
#     display: table;
#     clear: both;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     box-shadow: 0px 2px 20px rgba(0,0,0,.7);
#     position: relative;
#     z-index: 9998;
# }
#
# html[debug-cms=true] [debug="cms"]:hover {
#     border: 2px solid #54b200 !important;
# }
#
# html[debug-cms=true] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     background-color: #54b200 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
#
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover::before {
#     content: attr(data-params);
#     display: inline-block;
#     position: absolute;
#     right: 0;
#     bottom: 0;
#     left:auto;
#     top:auto;
#     z-index: 9999;
#     background-color: #EC7007 !important;
#     color: #fff !important;
#     padding: 5px;
#     word-break: break-all;
# }
# html[debug-cms=true] [debug="cms"] [debug="cms"],
# html[debug-cms=true] [debug="cms"] [debug="cms"]:hover{
#     border: 2px solid #EC7007 !important;
# }
#
# [debug="shoptext"] {
#     text-decoration: none !important;
#     border: 0 !important;
# }
#
# html[debug-shoptext=true] [debug="shoptext"] {
#     outline: 2px solid #ab65b2 !important;
#     position: relative;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover {
#     outline: 2px solid #833db2 !important;
#     z-index: 9999;
# }
#
# html[debug-shoptext=true] [debug="shoptext"]:hover::after {
#     background-color: #833db2 !important;
#     content: attr(title);
#     color: #fff !important;
#     position: absolute;
#     left: 0;
#     top: 0;
#     z-index: 9999;
#     padding-left: 2px;
#     padding-right: 2px;
#     font-size: 12px;
#     line-height: 1.2;
# }
# </style></meta></meta></head>
# <body class="">
# <div id="app">
# <header>
# <div class=" promotion-banner relative bg-primary text-white text-center px-3 py-2 hide">
# <div class="inline-block lg:ml-22">
# <span class="inline-block mb-2">
# <p><b>В связи с актуальной ситуацией отправка пакетов на Украину, в Россию и в Белоруссию, а также оформление заказов из этих стран, к сожалению невозможны.</b></p>
# </span>
# <a class="button-light ml-2" href="/versandkosten">Mehr</a>
# </div>
# <a class="absolute text-white flex items-center pin-r pin-y mr-3 ml-4" href="#">
# <span class="promotion-close">x</span>
# </a>
# </div>
# <aside class="hidden md:block">
# <div class="container container--wide">
# <div class="flex pt-3 pb-2 items-center justify-between border-b border-grey">
# <div class="hidden-print">
# </div>
# <div class="text-right">
# </div>
# <div></div>
# </div>
# </div>
# </aside>
# <div class="sticky pin-t z-10 md:relative container container--wide px-0">
# <div class="md:bg-transparent mx-auto flex flex-wrap md:flex-no-wrap items-center p-3 md:py-3 lg:pr-6 w-full justify-between flex-row">
# <a class="block w-64 sm:w-auto sm:max-w-full" href="https://www.aptekaru.de/" title="Стартовая страница">
# <img alt="Logo" src="/documents/logo/Logo Apteka 282x66.png"/>
# </a>
# <div class="user-nav md:order-last flex my-3 md:my-0">
# <a @click.prevent="emitEvent('offcanvas_open_account')" class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary" href="https://www.aptekaru.de/account/login" title="Зарегистрируйтесь здесь.">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-login-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-login.svg"/>
# </div>
# <div class="hidden sm:block">Войти</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary relative" href="https://www.aptekaru.de/notepad">
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-merkzettel-hover.svg?v=1"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-merkzettel.svg"/>
# </div>
# <div class="hidden sm:block">Список отложенных товаров</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:pr-0 relative" href="https://www.aptekaru.de/checkout/cart">
# <mini-cart class="text-sm"></mini-cart>
# <div class="sm:w-16 m-auto">
# <img class="icon-nav__hover w-16" src="/assets/master/img/design/icons/icon-cart-hover.svg"/><img class="icon-nav__regular w-16" src="/assets/master/img/design/icons/icon-cart.svg"/>
# </div>
# <div class="hidden sm:block">Корзина</div>
# </a>
# <a class="-ml-2 sm:-ml-0 text-xs text-center w-20 sm:w-auto text-grey-darker px-1 sm:px-2 lg:px-4 mx-1 sm:mx-0 icon-nav hover:text-primary lg:hidden flex flex-col justify-between -mr-1 sm:-mr-0 pr-0" href="#mobileNavigation" id="mobileNavigationButton" title="Все категории">
# <i class="fa fa-bars text-5xl mt-1" id="mobileNavigationIcon"></i>
# <div class="hidden sm:block">МЕНЮ</div>
# </a>
# </div>
# <speedfinder-search :is-primary="true" :is-products-only="false" :min-search-text-length="speedfinder.minSearchTextLength" :overwrite-search-term="speedfinder.searchTerm" @speedfinder_search_term_changed="onSpeedfinderSearchTermChange" class="w-full h-16 xl:ml-16 md:h-24 md:max-w-sm lg:max-w-md xl:max-w-lg">
# <form action="https://www.aptekaru.de/suche.html" class="w-full h-16 xl:ml-16 md:h-24" method="GET">
# <div class="relative bg-white z-10 flex shadow-md h-full">
# <input autocomplete="off" class="w-full pl-3" maxlength="128" name="term" placeholder="Товар, фармацевтический номер, действующее вещество..." type="text"/>
# <button class="bg-grey-light-dark hover:bg-grey-light-darker text-white text-base md:text-4xl m-0 px-4" tabindex="-1" type="submit" value="1">
# <i class="fa fa-search"></i>
# </button>
# </div>
# </form>
# </speedfinder-search>
# </div>
# </div>
# <div class="bg-grey">
# <div class="container container--mid relative page-wrap-top hidden sm:block">
# <img class="absolute pin-r -mt-2 hidden lg:block" src="/assets/master/img/design/apotheken-a-rund.png" style="z-index: 1;"/>
# <nav class="navmenu c-navmenu py-3 hidden-xs hidden-sm hidden-print">
# <ul class="o-nav o-nav__level o-nav__level--1 o-nav--inline "><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop" title="Все категории">Все категории</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a class=" active" href="/online-shop/allergie-heuschnupfen" title="Аллергия и аллергический ринит">Аллергия и аллергический ринит</a></li><li class="o-nav__item"><a href="/online-shop/alles-fuer-die-frau" title="Все для женщин">Все для женщин</a></li><li class="o-nav__item"><a href="/online-shop/augen-nase-ohren" title="Глаза, нос, уши">Глаза, нос, уши</a></li><li class="o-nav__item"><a href="/online-shop/augenpflege" title="Уход за глазами">Уход за глазами</a></li><li class="o-nav__item"><a href="/online-shop/buecher-cd-dvd" title="Книги, CD и DVD">Книги, CD и DVD</a></li><li class="o-nav__item"><a href="/online-shop/diabetes" title="Диабет">Диабет</a></li><li class="o-nav__item"><a href="/online-shop/erkaeltung-abwehr" title="Простуда и профилактика">Простуда и профилактика</a></li><li class="o-nav__item"><a href="/online-shop/familie" title="Семья">Семья</a></li><li class="o-nav__item"><a href="/online-shop/fitness" title="Фитнес">Фитнес</a></li><li class="o-nav__item"><a href="/online-shop/geschenkideen" title="Идеи для подарков">Идеи для подарков</a></li><li class="o-nav__item"><a href="/online-shop/haus-reiseapotheke" title="Домашняя аптечка и аптечка для путешествий">Домашняя аптечка и аптечка для путешествий</a></li><li class="o-nav__item"><a href="/online-shop/haeusliche-pflege" title="Медицинская помощь на дому">Медицинская помощь на дому</a></li><li class="o-nav__item"><a href="/online-shop/haut-haare-naegel" title="Кожа, волосы, ногти">Кожа, волосы, ногти</a></li><li class="o-nav__item"><a href="/online-shop/herz-kreislauf-venen" title="Сердце, система кровообращения и вены">Сердце, система кровообращения и вены</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik" title="Косметика">Косметика</a></li><li class="o-nav__item"><a href="/online-shop/magen-darm-verdauung" title="Желудок, кишечник и пищеварение">Желудок, кишечник и пищеварение</a></li><li class="o-nav__item"><a href="/online-shop/marken" title="Марки">Марки</a></li><li class="o-nav__item"><a href="/online-shop/medizinische-geraete" title="Медицинские приборы">Медицинские приборы</a></li><li class="o-nav__item"><a href="/online-shop/muskeln-knochen-gelenke" title="Мышцы, кости и суставы">Мышцы, кости и суставы</a></li><li class="o-nav__item"><a href="/online-shop/nahrungsergaenzung" title="Пищевые добавки">Пищевые добавки</a></li><li class="o-nav__item"><a href="/online-shop/natur-pflanzenheilkunde" title="Натуральные и растительные лекарственные средства">Натуральные и растительные лекарственные средства</a></li><li class="o-nav__item"><a href="/online-shop/nerven-beruhigung-schlaf" title="Средства для нервной системы, успокоения и хорошего сна">Средства для нервной системы, успокоения и хорошего сна</a></li><li class="o-nav__item"><a href="/online-shop/neu-im-sortiment" title="Новое в ассортименте">Новое в ассортименте</a></li><li class="o-nav__item"><a href="/online-shop/niere-blase-prostata" title="Почки, мочевой пузырь и простата">Почки, мочевой пузырь и простата</a></li><li class="o-nav__item"><a href="/online-shop/praxisbedarf" title="Товары для клиник">Товары для клиник</a></li><li class="o-nav__item"><a href="/online-shop/raucherentwoehnung" title="Борьба с курением">Борьба с курением</a></li><li class="o-nav__item"><a href="/online-shop/sale" title="Распродажа">Распродажа</a></li><li class="o-nav__item"><a href="/online-shop/schmerzmittel" title="Болеутоляющие средства">Болеутоляющие средства</a></li><li class="o-nav__item"><a href="/online-shop/sexualitaet" title="Половая жизнь">Половая жизнь</a></li><li class="o-nav__item"><a href="/online-shop/staerkung-konzentration" title="Укрепление здоровья и большая концентрация">Укрепление здоровья и большая концентрация</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter" title="Чаи и травы">Чаи и травы</a></li><li class="o-nav__item"><a href="/online-shop/themen" title="Разделы">Разделы</a></li><li class ...
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/marken" title="Марки">Марки</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a href="/online-shop/marken/avene" title="Avene">Avene</a></li><li class="o-nav__item"><a href="/online-shop/marken/dhu-schuessler-salze" title="Соли DHU Schüßler Salze">Соли DHU Schüßler Salze</a></li><li class="o-nav__item"><a href="/online-shop/marken/eucerin" title="Eucerin">Eucerin</a></li><li class="o-nav__item"><a href="/online-shop/marken/fenistil" title="Fenistil">Fenistil</a></li><li class="o-nav__item"><a href="/online-shop/marken/louis-widmer" title="Louis Widmer">Louis Widmer</a></li><li class="o-nav__item"><a href="/online-shop/marken/ratiopharm" title="ratiopharm">ratiopharm</a></li><li class="o-nav__item"><a href="/online-shop/marken/la-roche-posay" title="La Roche Posay">La Roche Posay</a></li><li class="o-nav__item"><a href="/online-shop/marken/vichy" title="Vichy">Vichy</a></li><li class="o-nav__item"><a href="/online-shop/marken" title="Все">Все</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/kosmetik" title="Косметика">Косметика</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a href="/online-shop/kosmetik/gesicht" title="Для лица">Для лица</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/haare" title="Волосы">Волосы</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/hand-fuss" title="Для ухода за кожей рук и ног">Для ухода за кожей рук и ног</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/koerper" title="Для тела">Для тела</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/make-up" title="Декоративная косметика">Декоративная косметика</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/maennerpflege" title="Средства по уходу для мужчин">Средства по уходу для мужчин</a></li><li class="o-nav__item"><a href="/online-shop/kosmetik/sonnenschutz-pflege" title="Солнцезащитные средства">Солнцезащитные средства</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/haut-haare-naegel" title="Кожа, волосы, ногти">Кожа, волосы, ногти</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a href="/online-shop/haut-haare-naegel/haut" title="Для кожи">Для кожи</a></li><li class="o-nav__item"><a href="/online-shop/haut-haare-naegel/naegel" title="Ногти">Ногти</a></li><li class="o-nav__item"><a href="/online-shop/haut-haare-naegel/sonstiges" title="Прочее">Прочее</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/raucherentwoehnung" title="Борьба с курением">Борьба с курением</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a href="/online-shop/raucherentwoehnung/e-zigaretten" title="Электронные сигареты">Электронные сигареты</a></li><li class="o-nav__item"><a href="/online-shop/raucherentwoehnung/inhaler" title="Ингалятор">Ингалятор</a></li><li class="o-nav__item"><a href="/online-shop/raucherentwoehnung/kaugummis" title="Жевательная резинка">Жевательная резинка</a></li><li class="o-nav__item"><a href="/online-shop/raucherentwoehnung/lutschtabletten" title="Таблетки для рассасывания">Таблетки для рассасывания</a></li><li class="o-nav__item"><a href="/online-shop/raucherentwoehnung/pflaster" title="Пластыри">Пластыри</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/tees-kraeuter" title="Чаи и травы">Чаи и травы</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/abfuehrtee" title="Послаблающие чаи">Послаблающие чаи</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/arznei-wellnesstee" title="Лекарственные чаи и чаи для оздоровления">Лекарственные чаи и чаи для оздоровления</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/bio-tee" title="Биочаи">Биочаи</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/erkaeltungstee" title="Чаи против простуды">Чаи против простуды</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/haus-wellnesstee" title="Домашние чаи и чаи для оздоровления">Домашние чаи и чаи для оздоровления</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/kindertee" title="Детские чаи">Детские чаи</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/loser-tee-filterbeutel" title="Рассыпной чай и фильтр-пакеты">Рассыпной чай и фильтр-пакеты</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/magen-darmtee" title="Чаи для желудка и кишечника">Чаи для желудка и кишечника</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/nieren-blasentee" title="Чаи для почек и мочевого пузыря">Чаи для почек и мочевого пузыря</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/schlaf-nerventee" title="Чаи для укрепления нервной системы и хорошего сна">Чаи для укрепления нервной системы и хорошего сна</a></li><li class="o-nav__item"><a href="/online-shop/tees-kraeuter/teezubehoer" title="Товары для приготовления чая">Товары для приготовления чая</a></li></ul>
# </li><li class="o-nav__item o-nav__item--has-children"><a href="/online-shop/zahn-mundpflege" title="Уход за ротовой полостью и зубами">Уход за ротовой полостью и зубами</a>
# <ul class="o-nav o-nav__level o-nav__level--2 "><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/atemfrische" title="Свежесть дыхания">Свежесть дыхания</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/mundduschen" title="Ирригаторы">Ирригаторы</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/mundtrockenheit" title="Сухость во рту">Сухость во рту</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/mundwasser-spuelungen" title="Ополаскиватели и жидкости для полоскания рта">Ополаскиватели и жидкости для полоскания рта</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnaufhellung" title="Отбеливание зубов">Отбеливание зубов</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnbuersten" title="Зубные щетки">Зубные щетки</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnersatz" title="Зубные протезы">Зубные протезы</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnfleischentzuendung" title="Гингивит">Гингивит</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnpasta-zahncreme" title="Зубная паста">Зубная паста</a></li><li class="o-nav__item"><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer" title="Сопутсвтующие товары по уходу за полостью рта">Сопутсвтующие товары по уходу за полостью рта</a></li></ul>
# </li></ul>
# </nav>
# </div>
# </div>
# </header>
# <div>
# <div class="container my-2">
# </div>
# </div>
# <main class="section-main container page-wrap-bottom">
# <ol class="breadcrumb bg-transparent">
# <li><a class="text-grey-darker hover:text-grey-dark text-sm" href="https://www.aptekaru.de/" title="Стартовая страница">Стартовая страница</a></li>
# <li><a class="text-grey-darker hover:text-grey-dark text-sm" href="/online-shop/allergie-heuschnupfen" title="Аллергия и аллергический ринит">Аллергия и аллергический ринит</a></li>
# <li class="active text-grey-darker text-sm">Lorano akut Tabletten</li>
# </ol>
# <div class="row">
# <div class="col-xs-12">
# <div id="ajaxProduct">
# <div class="row" id="details">
# <div class="col-sm-6 hidden-xs hidden-print">
# <div class="text-center">
# <div class="product-photo hidden-print">
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 mr-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-48 %<sup>1</sup></span>
# </div>
# <a @click.prevent="modal('modal640b03038a5a8')" href="/documents/products/Zoom/1009200670.jpg?ver=1677228009" title="Lorano akut Tabletten">
# <img alt="Lorano akut Tabletten" id="image42677" src="/documents/products/Detailansicht/1009200670.jpg?ver=1677228009" title="Lorano akut Tabletten">
# </img></a>
# <modal modal-id="modal640b03038a5a8" title="Lorano akut Tabletten">
# <div slot="body"><img alt="Lorano akut Tabletten" src="/documents/products/Zoom/1009200670.jpg?ver=1677228009"/></div>
# </modal>
# </div>
# </div>
# <p class="text-xs">Изображение схожее</p>
# </div>
# <div class="col-sm-6">
# <div class="bg-grey-light">
# <div class="p-4 pb-3 sm:pb-4">
# <h1 class="h2 mt-0 sm:mb-6"><span>Lorano akut Tabletten</span> 20 St</h1>
# <div class="hidden-lg hidden-md hidden-sm mb-2">
# <div class="row">
# <div class="col-xs-12 col-sm-5 col-lg-8 col-sm-offset-3">
# <div class="product-photo hidden-print">
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 mr-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-48 %<sup>1</sup></span>
# </div>
# <a @click.prevent="modal('modal640b03038a714')" href="/documents/products/Zoom/1009200670.jpg?ver=1677228009" title="Lorano akut Tabletten">
# <img alt="Lorano akut Tabletten" id="image42677" src="/documents/products/Detailansicht/1009200670.jpg?ver=1677228009" title="Lorano akut Tabletten">
# </img></a>
# <modal modal-id="modal640b03038a714" title="Lorano akut Tabletten">
# <div slot="body"><img alt="Lorano akut Tabletten" src="/documents/products/Zoom/1009200670.jpg?ver=1677228009"/></div>
# </modal>
# </div>
# </div>
# </div>
# </div>
# <div class="flex flex-wrap -mx-3">
# <div class="w-full sm:w-1/2 px-3 mb-2 sm:mb-4">
# <div class="information mb-3">
#                                     Zur Behandlung der Beschwerden bei allergischen Entzündungen.
#                                 </div>
# <div class="font-sari">
#                                 Форма выпуска: Tabletten
#                             </div>
# <div>
# <span class="font-sari">Содержание:</span> 20 St
#                         </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 07222502
#                                 </div>
# <div class="font-sari">
#                                     Производитель: Hexal AG
#                                 </div>
# </div>
# <div class="w-full sm:w-1/2 px-3">
# <div>
# <p class="price-details text-grey-darker text-4xl font-sans font-bold mb-0">
# <span class=" text-secondary ">5,19 €</span>
# <span class="small">
# <span class="saving text-sm text-grey-darker font-normal">вместо 10,02 €
#
#                     UVP
#                 </span>
# </span>
# </p>
# </div>
# <p class="small">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# <p> <img alt="поставка невозможна" class="delivery-time-image" src="/documents/delivery_times/delivery-empty.png" title="поставка невозможна"> <small> поставка невозможна</small></img></p>
# <p>
# <a class="text-grey-darker hover:text-grey-dark underline" href="/documents/products/PDF/1005934969.pdf?ver=1677228009" target="_blank">
# <i aria-hidden="true" class="fa fa-file-pdf-o fa-fw mr-1"></i>1005934969
#                                         </a>
# </p>
# <div class="productActions hidden-print">
# <p><a href="https://www.aptekaru.de/productrating/42677"><i class="fa fa-fw fa-star"></i> Оценки</a></p>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div class="row mt-3">
# <div class="px-6">
# <div class="alert alert-warning">
# <p>Данный товар не может быть доставлен. Помощь в подборе альтернативного товара: +49 (3491) 877 01 91</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="hidden-lg hidden-md hidden-sm mt-2 mb-2">
# <p class="text-xs">Изображение схожее</p>
# </div>
# <div class="row flex flex-col-reverse xl:flex-row">
# <div class="col-lg-6 hidden-print">
# <div class="variantsborder">
# <h2 class="h2 text-primary mb-6">Подходящие товары:</h2>
# <div class="row">
# <div class="col-xs-12 mb-4">
# <div class="package-size-product border-b md:border-0 border-grey pb-4 md:pb-0">
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://www.aptekaru.de/checkout/cart/add/product/11581" class="add-product flex flex-col md:flex-row justify-between" id="prod11581" method="post">
# <div>
# <img class="mr-4" src="/documents/products/Listenansicht/1009200673.jpg?ver=1677228009" style="width: 50px;"/>
# </div>
# <a class="block mr-4 mb-2 md:mb-0 text-grey-darker hover:text-primary" href="/online-kaufen/lorano-akut-tabletten-01797130">
# <div>Lorano akut Tabletten</div>
# <div class="text-xs">Tabletten</div>
# <div class="text-xs">7 St</div>
# </a>
# <div class="w-48">
# <input name="product[product_id]" type="hidden" value="11581">
# <input name="product[quantity]" type="hidden" value="1"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="price-info mb-2 md:mb-0">
# <div class="price text-grey-darker">
# <span class=" text-grey-darker ">4,36 € <span class="small">inkl. MwSt.</span></span>
# </div>
# <div class="description">
# <div>
# </div>
# </div>
# </div>
# </input></div>
# <div>
# <button class="md:ml-4">
# <img class="inline" src="/assets/master/img/design/icons/icon-cart-hover.png" width="30px"/>
# </button>
# </div>
# </form>
# </div>
# </div>
# <div class="col-xs-12 mb-4">
# <div class="package-size-product border-b md:border-0 border-grey pb-4 md:pb-0">
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://www.aptekaru.de/checkout/cart/add/product/42678" class="add-product flex flex-col md:flex-row justify-between" id="prod42678" method="post">
# <div>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full md:mr-3 ml-2 md:ml-0 pin-l w-12 h-12 text-xs">
# <span class="my-auto">-52 %<sup>1</sup></span>
# </div>
# <img class="mr-4" src="/documents/products/Listenansicht/1009200667.jpg?ver=1677228009" style="width: 50px;"/>
# </div>
# <a class="block mr-4 mb-2 md:mb-0 text-grey-darker hover:text-primary" href="/online-kaufen/lorano-akut-tabletten-07222904">
# <div>Lorano akut Tabletten</div>
# <div class="text-xs">Tabletten</div>
# <div class="text-xs">50 St</div>
# </a>
# <div class="w-48">
# <input name="product[product_id]" type="hidden" value="42678"/>
# <input name="product[quantity]" type="hidden" value="1"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="price-info mb-2 md:mb-0">
# <div class="price text-grey-darker">
# <span class=" text-secondary ">10,59 € <span class="small">inkl. MwSt.</span></span>
# </div>
# <div class="description">
# <div class="text-xs">вместо
#                                                 22,24 €
#                                             </div>
# <div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <button class="md:ml-4">
# <img class="inline" src="/assets/master/img/design/icons/icon-cart-hover.png" width="30px"/>
# </button>
# </div>
# </form>
# </div>
# </div>
# <div class="col-xs-12 mb-4">
# <div class="package-size-product border-b md:border-0 border-grey pb-4 md:pb-0">
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://www.aptekaru.de/checkout/cart/add/product/42679" class="add-product flex flex-col md:flex-row justify-between" id="prod42679" method="post">
# <div>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full md:mr-3 ml-2 md:ml-0 pin-l w-12 h-12 text-xs">
# <span class="my-auto">-52 %<sup>1</sup></span>
# </div>
# <img class="mr-4" src="/documents/products/Listenansicht/1009200662.jpg?ver=1677228009" style="width: 50px;"/>
# </div>
# <a class="block mr-4 mb-2 md:mb-0 text-grey-darker hover:text-primary" href="/online-kaufen/lorano-akut-tabletten-07224435">
# <div>Lorano akut Tabletten</div>
# <div class="text-xs">Tabletten</div>
# <div class="text-xs">100 St</div>
# </a>
# <div class="w-48">
# <input name="product[product_id]" type="hidden" value="42679"/>
# <input name="product[quantity]" type="hidden" value="1"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="price-info mb-2 md:mb-0">
# <div class="price text-grey-darker">
# <span class=" text-secondary ">19,49 € <span class="small">inkl. MwSt.</span></span>
# </div>
# <div class="description">
# <div class="text-xs">вместо
#                                                 40,72 €
#                                             </div>
# <div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <button class="md:ml-4">
# <img class="inline" src="/assets/master/img/design/icons/icon-cart-hover.png" width="30px"/>
# </button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <div class="col-lg-6 hidden-xs hidden-print">
# <div class="my-4">
# <p class="text-xs">
# </p>
# </div>
# </div>
# </div>
# <div class="inlay"><strong>Wichtige Hinweise (Pflichtangaben):<br/><br/>Lorano® akut 10 mg Tabletten</strong>. Wirkstoff: Loratadin. Anwendungsgebiete: Zur Behandlung der Beschwerden bei allergischen Entzündungen im Inneren der Nase, z. B. Heuschnupfen, und bei chronischer Nesselsucht unbekannter Ursache. <strong>Warnhinweis:</strong> Enthält Lactose.<br/><br/><strong>Zu Risiken und Nebenwirkungen lesen Sie die Packungsbeilage und fragen Sie Ihren Arzt oder Apotheker.</strong><br/><br/><br/>GEBRAUCHSINFORMATION: INFORMATION FÜR PATIENTEN<br/><br/>Lorano® akut 10 mg Tabletten<br/>Loratadin<br/><br/>Lesen Sie die gesamte Packungsbeilage sorgfältig durch, bevor Sie mit der Einnahme dieses Arzneimittels beginnen, denn sie enthält wichtige Informationen.<br/>Nehmen Sie dieses Arzneimittel immer genau wie in dieser Packungsbeilage beschrieben bzw. genau nach Anweisung Ihres Arztes oder Apothekers ein.<br/><ul style="padding-left: 20px;"><li>Heben Sie die Packungsbeilage auf. Vielleicht möchten Sie diese später nochmals lesen.</li><li>Fragen Sie Ihren Apotheker, wenn Sie weitere Informationen oder einen Rat benötigen.</li><li>Wenn Sie Nebenwirkungen bemerken, wen
# <div class="product-box-container flex col-sm-4 col-lg-3 col-xs-12 mb-4">
# <div class="bg-white product-box flex ">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/nurofen-ibuprofen-ueberz-tabletten-bei-kopfschmerzen-400-mg-08794436" title="Nurofen Ibuprofen überz. Tabletten bei Kopfschmerzen 400 mg">
# <img alt="Nurofen Ibuprofen überz. Tabletten bei Kopfschmerzen 400 mg" src="/documents/products/Listenansicht/1006869571.jpg?ver=1677228009" style="margin: auto" title="Nurofen Ibuprofen überz. Tabletten bei Kopfschmerzen 400 mg">
# </img></a>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/nurofen-ibuprofen-ueberz-tabletten-bei-kopfschmerzen-400-mg-08794436" title="Nurofen Ibuprofen überz. Tabletten bei Kopfschmerzen 400 mg">Nurofen Ibuprofen überz. Tabletten bei Kopfschmerzen 400 mg</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Überzogene Tabletten</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 24 St
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 08794436
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> Reckitt Benckiser Deutschland GmbH
#                                                                     </div>
# <p class="delivery-time"> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 24 St
#                                     <div class="pull-right">
# </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-grey-darker ">
#
#                                         7,15 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# </div>
# <p class="small product-shipping-info">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# </div>
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://www.aptekaru.de/checkout/cart/add/product" class="text-right flex-1 justify-end product-submit-form" method="post">
# <input name="product[product_id]" type="hidden" value="47532"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="quantity-picker flex ">
# <button @click.prevent="stepDown('quantity640b0303a3f54')" class="quantity-picker__minus text-grey-dark" href="#" type="button">
# <i class="fa fa-minus"></i>
# </button>
# <input autocomplete="off" class="quantity-picker__field text-grey-dark " id="quantity640b0303a3f54" min="1" name="product[quantity]" step="1" type="number" value="1"/>
# <button @click.prevent="stepUp('quantity640b0303a3f54')" class="quantity-picker__plus text-grey-dark" href="#" type="button">
# <i class="fa fa-plus"></i>
# </button>
# </div>
# <button class="product-box__tocart text-white bg-secondary px-2 md:w-full" name="refresh_submit" title="В корзину" type="submit" value=""><i class="fa fa-shopping-cart"></i><span class="text-base"> добавлено в  корзину.</span></button>
# </form>
# </div>
# </div>
# </div>
# <div class="product-box-container flex col-sm-4 col-lg-3 col-xs-12 mb-4">
# <div class="bg-white product-box flex ">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/euphorbium-comp-nasentropfen-sn-01230044" title="Euphorbium comp. Nasentropfen SN">
# <img alt="Euphorbium comp. Nasentropfen SN" src="/documents/products/Listenansicht/1010135633.jpg?ver=1677228009" style="margin: auto" title="Euphorbium comp. Nasentropfen SN">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-34 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/euphorbium-comp-nasentropfen-sn-01230044" title="Euphorbium comp. Nasentropfen SN">Euphorbium comp. Nasentropfen SN</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Nasendosierspray</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 20 ml
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 01230044
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> Biologische Heilmittel Heel GmbH
#                                                                     </div>
# <p class="delivery-time"> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 20 ml
#                                     <div class="pull-right">
# <span class="font-sari base-price-label">Базовый тариф:</span>
#                                                                                                                             305,50 € / 1 l
#                                                                             </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# <div class="line-through">
#                                         9,38 €
#                                     </div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-secondary ">
#
#                                         6,11 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# <div class="product-box__meta_p mb-0 base-price">
# <span class="font-sari base-price-label">Базовый тариф:</span>
#                                         20 ml |
#                                         305,50 € / 1 l
#                                     </div>
# </div>
# <p class="small product-shipping-info">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# </div>
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://www.aptekaru.de/checkout/cart/add/product" class="text-right flex-1 justify-end product-submit-form" method="post">
# <input name="product[product_id]" type="hidden" value="8170"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="quantity-picker flex ">
# <button @click.prevent="stepDown('quantity640b0303a43ff')" class="quantity-picker__minus text-grey-dark" href="#" type="button">
# <i class="fa fa-minus"></i>
# </button>
# <input autocomplete="off" class="quantity-picker__field text-grey-dark " id="quantity640b0303a43ff" min="1" name="product[quantity]" step="1" type="number" value="1"/>
# <button @click.prevent="stepUp('quantity640b0303a43ff')" class="quantity-picker__plus text-grey-dark" href="#" type="button">
# <i class="fa fa-plus"></i>
# </button>
# </div>
# <button class="product-box__tocart text-white bg-secondary px-2 md:w-full" name="refresh_submit" title="В корзину" type="submit" value=""><i class="fa fa-shopping-cart"></i><span class="text-base"> добавлено в  корзину.</span></button>
# </form>
# </div>
# </div>
# </div>
# <div class="product-box-container flex col-sm-4 col-lg-3 col-xs-12 mb-4">
# <div class="bg-white product-box flex ">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/vigantol-1-000-i-e-vitamin-d3-tabletten-13155690" title="Vigantol 1.000 I.E. Vitamin D3 Tabletten">
# <img alt="Vigantol 1.000 I.E. Vitamin D3 Tabletten" src="/documents/products/Listenansicht/1006233851.jpg?ver=1677228009" style="margin: auto" title="Vigantol 1.000 I.E. Vitamin D3 Tabletten">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
# <span class="my-auto">-35 %<sup>1</sup></span>
# </div>
# </div>
# <div class="product-box__meta">
# <div class="productrating">
# </div>
# <h4 class="product-box__title mt-0 mb-2"><a class="text-grey-darker h4 text-base mb-0" href="/online-kaufen/vigantol-1-000-i-e-vitamin-d3-tabletten-13155690" title="Vigantol 1.000 I.E. Vitamin D3 Tabletten">Vigantol 1.000 I.E. Vitamin D3 Tabletten</a></h4>
# <div class="list-meta">
# <div>
# <span class="font-sari">Форма выпуска: Tabletten</span>
# </div>
# <div>
# <span class="font-sari">Содержание:</span> 200 St
#                                     </div>
# <div>
# <span class="font-sari">Фармацевтический номер:</span> 13155690
#                                 </div>
# <div>
# <span class="font-sari">Производитель:</span> WICK Pharma - Zweigniederlassung der Procter &amp; Gamble GmbH
#                                                                     </div>
# <p class="delivery-time"> <img alt="в наличии" class="delivery-time-image" src="/documents/delivery_times/delivery-three.png" title="в наличии"> <small> в наличии</small></img></p>
# </div>
# </div>
# <div class="product-box__bottom">
# <div class="product-box__bottom__wrap text-grey-dark base-price-boxed">
#
#                                                                 200 St
#                                     <div class="pull-right">
# </div>
# </div>
# <div class="product-box__bottom__wrap">
# <div>
# <div class="line-through">
#                                         16,48 €
#                                     </div>
# </div>
# <div class="product-box__price">
# <div class="mb-0 text-base text-secondary ">
#
#                                         10,69 €
#
#                                     </div>
# </div>
# <div class="base-price-list text-grey-dark">
# </div>
# <p class="small product-shipping-info">
#                                                                     Вкл. НДС"
#                                                                 при необходимости включая <a data-target="#content-modal" data-title="Versandkosten" data-toggle="content-modal" href="/ajax/content/versandkosten.20005.html" rel="nofollow">стоимость доставки</a>
# </p>
# </div>
# <form @submit.prevent="emitEvent('cart_update', $event)" action="https://www.aptekaru.de/checkout/cart/add/product" class="text-right flex-1 justify-end product-submit-form" method="post">
# <input name="product[product_id]" type="hidden" value="55532"/>
# <input name="options[PrescriptionType]" type="hidden" value="0"/>
# <div class="quantity-picker flex ">
# <button @click.prevent="stepDown('quantity640b0303a478d')" class="quantity-picker__minus text-grey-dark" href="#" type="button">
# <i class="fa fa-minus"></i>
# </button>
# <input autocomplete="off" class="quantity-picker__field text-grey-dark " id="quantity640b0303a478d" min="1" name="product[quantity]" step="1" type="number" value="1"/>
# <button @click.prevent="stepUp('quantity640b0303a478d')" class="quantity-picker__plus text-grey-dark" href="#" type="button">
# <i class="fa fa-plus"></i>
# </button>
# </div>
# <button class="product-box__tocart text-white bg-secondary px-2 md:w-full" name="refresh_submit" title="В корзину" type="submit" value=""><i class="fa fa-shopping-cart"></i><span class="text-base"> добавлено в  корзину.</span></button>
# </form>
# </div>
# </div>
# </div>
# <div class="product-box-container flex col-sm-4 col-lg-3 col-xs-12 mb-4">
# <div class="bg-white product-box flex ">
# <div class="product-box__image text-center p-0 md:p-2">
# <a href="/online-kaufen/grippostad-c-hartkapseln-00571748" title="Grippostad C Hartkapseln">
# <img alt="Grippostad C Hartkapseln" src="/documents/products/Listenansicht/1008376293.jpg?ver=1677228009" style="margin: auto" title="Grippostad C Hartkapseln">
# </img></a>
# <div class="bg-primary text-white flex flex-col justify-between text-center leading-none absolute pin-t z-1 rounded-full mt-3 pin-r w-24 h-24 text-base">
a></li></ul>
# </ul></li><li><a href="/online-shop/zahn-mundpflege/mundtrockenheit" title="Сухость во рту">Сухость во рту</a></li><li><a href="/online-shop/zahn-mundpflege/mundwasser-spuelungen" title="Ополаскиватели и жидкости для полоскания рта">Ополаскиватели и жидкости для полоскания рта</a></li><li><a href="/online-shop/zahn-mundpflege/zahnaufhellung" title="Отбеливание зубов">Отбеливание зубов</a></li><li><a href="/online-shop/zahn-mundpflege/zahnbuersten" title="Зубные щетки">Зубные щетки</a><ul>
# <ul class=""><li><a href="/online-shop/zahn-mundpflege/zahnbuersten/elektrische-zahnbuersten" title="Электрический зубные щетки ">Электрический зубные щетки </a></li><li><a href="/online-shop/zahn-mundpflege/zahnbuersten/ersatz-aufsteckbuersten" title="Запасные и съемные щетки">Запасные и съемные щетки</a></li><li><a href="/online-shop/zahn-mundpflege/zahnbuersten/handzahnbuersten" title="Зубные щетки">Зубные щетки</a></li><li><a href="/online-shop/zahn-mundpflege/zahnbuersten/interdentalbuersten" title="Сменные ершики для межзубных промежутков">Сменные ершики для межзубных промежутков</a></li></ul>
# </ul></li><li><a href="/online-shop/zahn-mundpflege/zahnersatz" title="Зубные протезы">Зубные протезы</a><ul>
# <ul class=""><li><a href="/online-shop/zahn-mundpflege/zahnersatz/aufbewahrung" title="Хранение">Хранение</a></li><li><a href="/online-shop/zahn-mundpflege/zahnersatz/haftmittel" title="Адгезивные средства">Адгезивные средства</a></li><li><a href="/online-shop/zahn-mundpflege/zahnersatz/reinigung" title="Очищение">Очищение</a></li></ul>
# </ul></li><li><a href="/online-shop/zahn-mundpflege/zahnfleischentzuendung" title="Гингивит">Гингивит</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpasta-zahncreme" title="Зубная паста">Зубная паста</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer" title="Сопутсвтующие товары по уходу за полостью рта">Сопутсвтующие товары по уходу за полостью рта</a><ul>
# <ul class=""><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/kaugummi" title="Жевательная резинка">Жевательная резинка</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/sonstiges" title="Прочее">Прочее</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/zahnseide-hoelzer" title="Зубная нить и зубочистки">Зубная нить и зубочистки</a></li><li><a href="/online-shop/zahn-mundpflege/zahnpflegezubehoer/zungenreiniger" title="Скребок для языка">Скребок для языка</a></li></ul>
# </ul></li></ul>
# </ul></li></ul>
# </ul>
# </nav>
# <script type="text/javascript">
#             available.objAvailable('shop', function (o) {
#                 o.initMMenu('#mobileNavigation', true);
#             });
#         </script>
# <script type="text/javascript">window.shoptexts = {'search': {'placeholder': 'На латинице: название, PZN или дейст. вещество','noResult': 'Нет результатов','products': 'Рекомендованные товары','goToAll': 'Показать все результаты','manufacturer': 'Производитель','productGroups': 'Категории','suggestions': 'Предложения','redirects': 'Переадрессация','searching': '""Поиск результатов..."','minimumCharactersPre': 'Поиск  должен как минимум','minimumCharactersAfter': 'содержать знаков.'},'cartSummary' : {'empty' : 'Корзина пуста.','total' : 'Промежуточная сумма','priceInfo' : 'Цены Вкл. НДС" при необходимости включая стоимость доставки','addedToCart': 'добавлено в  корзину.','toCheckout': 'К оплате','shippingHeadline': 'Не хватает до бесплатной доставки','edit': 'К корзине','continueShopping': 'Продолжить покупки','crossSellingHeadline': 'Любимые продукты','crossSellingGoToProduct': 'К товару',},'offcanvas': {'continueShopping': 'Продолжить покупки'},'modal': {'close' : 'Закрыть'},'notepad': {'add_to_notepad': 'В Списке отложенных товаров','remove_from_notepad': 'Vom Merkzettel entfernen'},'revocation': {'cancel_all': 'Я хочу отказаться от всего заказа','cancel_some': 'Я хочу отказаться от следующих товаров в заказе','product_number': 'Товар №','amount': 'Количество','add_product': 'Добавить товар'}}</script>
# <script src="/assets/master/tmp/main.min.3dd417cd.js" type="text/javascript"></script>
# <script>
#         let promoBanner = document.querySelector(".promotion-banner");
#         let promoButtonClose = document.querySelector(".promotion-close");
#         if (promoBanner) {
#             let userClass = promoBanner.classList[0];
#             let cookieName = 'promoBannerClosed' + userClass;
#             let userCookie = getCookie(cookieName);
#             if(userCookie != 'closed'){
#                 promoBanner.classList.remove("hide");
#             }
#             promoButtonClose.addEventListener('click', function(e){
#                 e.preventDefault();
#                 setCookie(cookieName, 'closed', 90)
#                 promoBanner.classList.add("hide");
#             });
#         }
#
#         function getCookie(cname) {
#             var name = cname + "=";
#             var decodedCookie = decodeURIComponent(document.cookie);
#             var ca = decodedCookie.split(';');
#             for(var i = 0; i <ca.length; i++) {
#                 var c = ca[i];
#                 while (c.charAt(0) == ' ') {
#                     c = c.substring(1);
#                 }
#                 if (c.indexOf(name) == 0) {
#                     return c.substring(name.length, c.length);
#                 }
#             }
#             return "";
#         }
#
#         function setCookie(cname, cvalue, exdays) {
#             var d = new Date();
#             d.setTime(d.getTime() + (exdays*24*60*60*1000));
#             var expires = "expires="+ d.toUTCString();
#             document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/";
#         }
#     </script>
# <noscript>
# <div id="javaScriptWarning" style="width: 100%; position:fixed; bottom: 0; left:0;z-index:1000;">
# <div style="background-color: #222;opacity:0.9;color: #FFFFFF;font-size: 13px;margin: 0 auto;padding: 8px;text-align: center;line-height:18px;">
#                             Javascript не активен. <br> Пожалуйста, активируйте Javascript в браузере, иначе будут доступны не все функции сайта.
#                         </br></div>
# </div>
# </noscript>
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K2FC265" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript><script>(function (init)
# {
#     var root = document.getElementsByTagName('html')[0];
#     root.setAttribute('debug-cms', true);
#     root.setAttribute('debug-shoptext', true);
#
#         })();</script></body>
# </html>

# %%
# Парсинг названия товара
name = soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text
name
# Out:
# 'Lorano akut Tabletten 20\xa0St'

# %%
import re

# %%
form = soup.find('div', text=re.compile('Форма выпуска:'))

# %%
form.get_text(strip=True)[15:]
# Out:
# 'Tabletten'

# %%
# Парсинг формы выпуска
form = soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:]
form
# Out:
# 'Tabletten'

# %%
# Парсинг содержания
content = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
content
# Out:
# 'Содержание:\n    20\xa0St'

# %%
content = int(re.findall(r'\d+', content)[0])
content
# Out:
# 20

# %%
# Парсинг производителя
manufacturer = soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:]
manufacturer
# Out:
# 'Hexal AG'

# %%
# Парсинг цены товара
price = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
price
# Out:
# '5,19\xa0€'

# %%
type(price)
# Out:
# str

# %%
price = price.replace(',', '.')

# %%
price = re.sub(r'[^\d.]+', '', price)
price
# Out:
# '5.19'

# %%
price = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
price = price.replace(',', '.')
price = re.sub(r'[^\d.]+', '', price)
float(price)
# Out:
# 5.19

# %%
float(price)

# %% [markdown]
# ### Объединяем все вместе - скрейпинг и парсинг информации о всех товарах одной страницы

# %%
# Пустые списки, которые будут содержать соответствующие данные: название, цена, форма выпуска, содержание, производитель
name =[]
price =[]
form = []
content =[]
manufacturer =[]

# %%
# Создание пустого словаря, который будет содержать все получаемые данные
output ={}

# %%
# Цикл по списку ссылок на товары
for i in url_joined:
  response = requests.get(i)
  soup = BeautifulSoup(response.content, 'html.parser')

# Парсинг названия товара. Обработка исключения: добавляем пустую строку.
  try:
    name.append(soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text)
  except:
    name.append('')

# Парсинг цены товара. 
  try:
    p = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
    p = p.replace(',', '.')
    p = float(re.sub(r'[^\d.]+', '', p))
    price.append(p)
  except:
    price.append('')

# Парсинг формы выпуска товара.
  try:
    form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
  except:
    form.append('')

# Парсинг содержания (веса) товара.  
  try:  
    cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
    cont = int(re.findall(r'\d+', cont)[0])
    content.append(cont)
  except:
    content.append('')

# Парсинг производителя товара.
  try:
    manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])
  except:
    manufacturer.append('')

# Записываем данные в словарь
  output = {'Name' : name, 'Price' : price, 'Form' : form, 'Content' : content, 'Manufacturer' : manufacturer}

# %%
output
# Out:
# {'Name': ['Lorano akut Tabletten 20\xa0St',
#   'Desloratadin-ratiopharm 5 mg Filmtabletten 100\xa0St',
#   'Allegra Allergietabletten 20 mg Tabletten 50\xa0St',
#   'Vividrin Mometason Heuschnupfennasenspray 18\xa0g',
#   'Desloratadin Heumann 5 mg Filmtabletten 50\xa0St',
#   'AllergoPax Milbenspray 500\xa0ml',
#   'Ipalat Hydro Med Lutschpastillen 30\xa0St',
#   'Momekort 50 µg/Sprühstoß Nasenspray, Susp.140 für Erwachsene 18\xa0g',
#   '',
#   'Allegra Allergietabletten 20 mg Tabletten 6\xa0St',
#   'Allegra Allergietabletten 20 mg Tabletten 20\xa0St',
#   'MometaDex 50 µg/Sprühstoß Nasenspray 18\xa0g',
#   'MometaDex 50 µg/Sprühstoß Nasenspray 10\xa0g',
#   'Tavegil Tabletten 60\xa0St',
#   'Allergodil akut forte 1,5 mg/ml Nasenspray Lösung 10\xa0ml',
#   'ALLERGO-AZELIND von DoppelherzPharma 6\xa0ml',
#   'ALLERGO-MOMELIND von DoppelherzPharma 18\xa0g',
#   'ALLERGO-MOMELIND von DoppelherzPharma 10\xa0g',
#   'Astragalus Pro 500/50-Kapseln 60\xa0St',
#   'Tetesept Meerwasser Nasenspülsalz 20\xa0St',
#   'Levocetirizin Fairmed 5 mg Filmtabletten 100\xa0St',
#   'Levocetirizin Fairmed 5 mg Filmtabletten 20\xa0St',
#   'Levocetirizin Fairmed 5 mg Filmtabletten 10\xa0St',
#   'Daosin Tabletten 120\xa0St'],
#  'Price': [5.19,
#   18.89,
#   18.79,
#   12.69,
#   21.59,
#   49.95,
#   6.2,
#   18.2,
#   '',
#   4.91,
#   8.49,
#   6.69,
#   4.29,
#   18.97,
#   9.69,
#   6.2,
#   8.28,
#   5.47,
#   29.95,
#   5.52,
#   18.2,
#   4.68,
#   6.62,
#   92.59],
#  'Form': ['Tabletten',
#   'Filmtabletten',
#   'Tabletten',
#   'Nasenspray',
#   'Filmtabletten',
#   'Lösung',
#   'Pastillen',
#   'Nasenspray',
#   '',
#   'Tabletten',
#   'Tabletten',
#   'Nasenspray',
#   'Nasenspray',
#   'Tabletten',
#   'Nasenspray',
#   'Augentropfen',
#   'Nasendosierspray',
#   'Nasendosierspray',
#   'Kapseln',
#   'Salz',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Filmtabletten',
#   'Tabletten'],
#  'Content': [20,
#   100,
#   50,
#   18,
#   50,
#   500,
#   30,
#   18,
#   '',
#   6,
#   20,
#   18,
#   10,
#   60,
#   10,
#   6,
#   18,
#   10,
#   60,
#   20,
#   100,
#   20,
#   10,
#   120],
#  'Manufacturer': ['Hexal AG',
#   'ratiopharm GmbH',
#   'A. Nattermann & Cie GmbH',
#   'Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'Doromed GmbH',
#   'Dr. Pfleger Arzneimittel GmbH',
#   'DERMAPHARM AG',
#   '',
#   'A. Nattermann & Cie GmbH',
#   'A. Nattermann & Cie GmbH',
#   'Dexcel Pharma GmbH',
#   'Dexcel Pharma GmbH',
#   'STADA Consumer Health Deutschland GmbH',
#   'Viatris Healthcare GmbH',
#   'Queisser Pharma GmbH & Co. KG',
#   'Queisser Pharma GmbH & Co. KG',
#   'Queisser Pharma GmbH & Co. KG',
#   'Zein Pharma - Germany GmbH',
#   'Merz Consumer Care GmbH',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'HEUMANN PHARMA GmbH & Co. Generica KG',
#   'STADA Consumer Health Deutschland GmbH']}

# %%
# Создание pandas dataframe
df = pd.DataFrame(output)

# %%
df
# Out:
#                                                  Name  Price  \
# 0                         Lorano akut Tabletten 20 St   5.19
# 1   Desloratadin-ratiopharm 5 mg Filmtabletten 100 St  18.89
# 2     Allegra Allergietabletten 20 mg Tabletten 50 St  18.79
# 3      Vividrin Mometason Heuschnupfennasenspray 18 g  12.69
# 4       Desloratadin Heumann 5 mg Filmtabletten 50 St  21.59
# 5                       AllergoPax Milbenspray 500 ml  49.95
# 6              Ipalat Hydro Med Lutschpastillen 30 St    6.2
# 7   Momekort 50 µg/Sprühstoß Nasenspray, Susp.140 ...   18.2
# 8
# 9      Allegra Allergietabletten 20 mg Tabletten 6 St   4.91
# 10    Allegra Allergietabletten 20 mg Tabletten 20 St   8.49
# 11          MometaDex 50 µg/Sprühstoß Nasenspray 18 g   6.69
# 12          MometaDex 50 µg/Sprühstoß Nasenspray 10 g   4.29
# 13                            Tavegil Tabletten 60 St  18.97
# 14  Allergodil akut forte 1,5 mg/ml Nasenspray Lös...   9.69
# 15          ALLERGO-AZELIND von DoppelherzPharma 6 ml    6.2
# 16         ALLERGO-MOMELIND von DoppelherzPharma 18 g   8.28
# 17         ALLERGO-MOMELIND von DoppelherzPharma 10 g   5.47
# 18                Astragalus Pro 500/50-Kapseln 60 St  29.95
# 19            Tetesept Meerwasser Nasenspülsalz 20 St   5.52
# 20    Levocetirizin Fairmed 5 mg Filmtabletten 100 St   18.2
# 21     Levocetirizin Fairmed 5 mg Filmtabletten 20 St   4.68
# 22     Levocetirizin Fairmed 5 mg Filmtabletten 10 St   6.62
# 23                            Daosin Tabletten 120 St  92.59
#
#                 Form Content                              Manufacturer
# 0          Tabletten      20                                  Hexal AG
# 1      Filmtabletten     100                           ratiopharm GmbH
# 2          Tabletten      50                  A. Nattermann & Cie GmbH
# 3         Nasenspray      18  Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH
# 4      Filmtabletten      50     HEUMANN PHARMA GmbH & Co. Generica KG
# 5             Lösung     500                              Doromed GmbH
# 6          Pastillen      30             Dr. Pfleger Arzneimittel GmbH
# 7         Nasenspray      18                             DERMAPHARM AG
# 8
# 9          Tabletten       6                  A. Nattermann & Cie GmbH
# 10         Tabletten      20                  A. Nattermann & Cie GmbH
# 11        Nasenspray      18                        Dexcel Pharma GmbH
# 12        Nasenspray      10                        Dexcel Pharma GmbH
# 13         Tabletten      60    STADA Consumer Health Deutschland GmbH
# 14        Nasenspray      10                   Viatris Healthcare GmbH
# 15      Augentropfen       6             Queisser Pharma GmbH & Co. KG
# 16  Nasendosierspray      18             Queisser Pharma GmbH & Co. KG
# 17  Nasendosierspray      10             Queisser Pharma GmbH & Co. KG
# 18           Kapseln      60                Zein Pharma - Germany GmbH
# 19              Salz      20                   Merz Consumer Care GmbH
# 20     Filmtabletten     100     HEUMANN PHARMA GmbH & Co. Generica KG
# 21     Filmtabletten      20     HEUMANN PHARMA GmbH & Co. Generica KG
# 22     Filmtabletten      10     HEUMANN PHARMA GmbH & Co. Generica KG
# 23         Tabletten     120    STADA Consumer Health Deutschland GmbH

# %% [markdown]
# ## Скрейпинг нескольких страниц

# %%
name =[]
price =[]
form = []
content =[]
manufacturer =[]
output = {}

url_1 = 'https://www.aptekaru.de'
url = 'https://www.aptekaru.de/online-shop/allergie-heuschnupfen'

while True:
  
  page = requests.get(url)
  soup = BeautifulSoup(page.content, 'html.parser')
  next_page_link = soup.find('a', ('class', 'arrow next'))
  result = soup.find_all('div', ('class','product-box-container'))

  url_2 = []
  for i in result:
    for link in i.find_all('div', ('class','product-box__image')):
      url_2.append(link.find('a').get('href'))
  
  url_joined = []

  for link in url_2:
    url_joined.append(urllib.parse.urljoin(url_1, link))
  
  for i in url_joined:
    response = requests.get(i)

    soup = BeautifulSoup(response.content, 'html.parser')

    # Парсинг названия товара. Обработка исключения: добавляем пустую строку.
    try:
      name.append(soup.find('h1', ('class', 'h2 mt-0 sm:mb-6')).text)
    except:
      name.append('')

    # Парсинг цены товара. 
    try:
      p = soup.find('p',('class','price-details text-grey-darker text-4xl font-sans font-bold mb-0')).find('span').text
      p = p.replace(',', '.')
      p = float(re.sub(r'[^\d.]+', '', p))
      price.append(p)
    except:
      price.append('')

    # Парсинг формы выпуска товара.
    try:
      form.append(soup.find('div', text=re.compile('Форма выпуска:')).get_text(strip=True)[15:])
    except:
      form.append('')

    # Парсинг содержания (веса) товара.  
    try:  
      cont = soup.find('div', text=re.compile('Содержание:')).get_text(strip=True)
      cont = int(re.findall(r'\d+', cont)[0])
      content.append(cont)
    except:
      content.append('')

    # Парсинг производителя товара.
    try:
      manufacturer.append(soup.find('div', text=re.compile('Производитель:')).get_text(strip=True)[15:])
    except:
      manufacturer.append('')

    output = {'Name' : name, 'Price' : price, 'Form' : form, 'Content' : content, 'Manufacturer' : manufacturer}

  if not next_page_link:
    break
  
  url = url_1 + next_page_link['href']

# %%
df = pd.DataFrame(output)
df
# Out:
#                                                   Name  Price           Form  \
# 0                          Lorano akut Tabletten 20 St   5.19      Tabletten
# 1    Desloratadin-ratiopharm 5 mg Filmtabletten 100 St  18.89  Filmtabletten
# 2      Allegra Allergietabletten 20 mg Tabletten 50 St  18.79      Tabletten
# 3       Vividrin Mometason Heuschnupfennasenspray 18 g  12.69     Nasenspray
# 4        Desloratadin Heumann 5 mg Filmtabletten 50 St  21.59  Filmtabletten
# ..                                                 ...    ...            ...
# 130  Levocetirizin - 1 A Pharma 5 mg Filmtabletten ...  20.73  Filmtabletten
# 131  Levocetirizin - 1 A Pharma 5 mg Filmtabletten ...  17.75  Filmtabletten
# 132  Levocetirizin - 1 A Pharma 5 mg Filmtabletten ...   8.26  Filmtabletten
# 133  Levocetirizin HEXAL bei Allergien 5 mg Filmtab...  25.96  Filmtabletten
# 134  Levocetirizin HEXAL bei Allergien 5 mg Filmtab...  15.49  Filmtabletten
#
#     Content                              Manufacturer
# 0        20                                  Hexal AG
# 1       100                           ratiopharm GmbH
# 2        50                  A. Nattermann & Cie GmbH
# 3        18  Dr. Gerhard Mann Chem.-pharm.Fabrik GmbH
# 4        50     HEUMANN PHARMA GmbH & Co. Generica KG
# ..      ...                                       ...
# 130     100                           1 A Pharma GmbH
# 131      50                           1 A Pharma GmbH
# 132      20                           1 A Pharma GmbH
# 133     100                                  Hexal AG
# 134      50                                  Hexal AG
#
# [135 rows x 5 columns]

# %%
df.to_csv('remedies.csv')
